# %% [markdown]
# > *This notebook is part of the free course [EEwPython](https://colab.research.google.com/github/csaybar/EEwPython/blob/master/index.ipynb); the content is available [on GitHub](https://github.com/csaybar/EEwPython)* and released under the [Apache 2.0 License](https://www.gnu.org/licenses/gpl-3.0.en.html). 99% of this material has been adapted from [Google Earth Engine Guides](https://developers.google.com/earth-engine/).

# %% [markdown]
# <center>
# <h1>Google Earth Engine with Python </h1>
# <h2> ee.ImageCollection</h2>
# </center>
# <h2> Topics:</h2>
#
# 1. ImageCollection Overview
# 2. ImageCollection Information and Metadata
# 3. Filtering and ImageCollection
# 4. Mapping over an ImageCollection
# 5. Reducing an ImageCollection
# 6. Compositing and Mosaicking
# 7. Iterating over an ImageCollection
#
#
# An **ImageCollection** is a stack or time series of images. In addition to loading an **ImageCollection** using an Earth Engine collection ID, Earth Engine has methods to create image collections. The constructor **ee.ImageCollection()** or the convenience method **ee.ImageCollection.fromImages()** create image collections from lists of images. You can also create new image collections by merging existing collections.

# %% [markdown]
# ## Testing the software setup

# %%
# Earth Engine Python API
import ee
ee.Initialize()

# %%
import folium

# %%
def Mapdisplay(center, dicc, Tiles="OpensTreetMap",zoom_start=10):
    '''
    :param center: Center of the map (Latitude and Longitude).
    :param dicc: Earth Engine Geometries or Tiles dictionary
    :param Tiles: Mapbox Bright,Mapbox Control Room,Stamen Terrain,Stamen Toner,stamenwatercolor,cartodbpositron.
    :zoom_start: Initial zoom level for the map.
    :return: A folium.Map object.
    '''
    mapViz = folium.Map(location=center, tiles=Tiles, zoom_start=zoom_start)
    for k, v in dicc.items():
      if ee.image.Image in [type(x) for x in v.values()]:
        tiles = ee.data.getTileUrl(v, 8014, 4817, 37)
        tiles = tiles[:-12] + "{z}/{x}/{y}"
        folium.TileLayer(
            tiles = tiles,
            attr  = 'Google Earth Engine',
            overlay =True,
            name  = k
        ).add_to(mapViz)
      else:
        folium.GeoJson(
        data = v,
        name = k
          ).add_to(mapViz)
    mapViz.add_child(folium.LayerControl())
    return mapViz

# %% [markdown]
# # 1. Image Collection Overview
#
# An `ImageCollection` is a **stack or time series of images**. In addition to loading an `ImageCollection` using an Earth Engine collection ID, Earth Engine has methods to create image collections. The constructor `ee.ImageCollection()` or the convenience method `ee.ImageCollection.fromImages()` create image collections from lists of images. You can also create new image collections by merging existing collections. For example:

# %%
# Create arbitrary constant images.
constant1 = ee.Image(1)
constant2 = ee.Image(2)

# Create a collection by giving a list to the constructor.
collectionFromConstructor = ee.ImageCollection([constant1, constant2])
print('collectionFromConstructor: ')
collectionFromConstructor.getInfo()
# Out:
# collectionFromConstructor:
# {'type': 'ImageCollection',
#  'bands': [],
#  'features': [{'type': 'Image',
#    'bands': [{'id': 'constant',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 1,
#       'max': 1},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]}],
#    'properties': {'system:index': '0'}},
#   {'type': 'Image',
#    'bands': [{'id': 'constant',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 2,
#       'max': 2},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]}],
#    'properties': {'system:index': '1'}}]}

# %%
# Create a collection with fromImages().
collectionFromImages = ee.ImageCollection.fromImages([ee.Image(3), ee.Image(4)])
print('collectionFromImages: ')
collectionFromImages.getInfo()
# Out:
# collectionFromImages:
# {'type': 'ImageCollection',
#  'bands': [],
#  'features': [{'type': 'Image',
#    'bands': [{'id': 'constant',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 3,
#       'max': 3},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]}],
#    'properties': {'system:index': '0'}},
#   {'type': 'Image',
#    'bands': [{'id': 'constant',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 4,
#       'max': 4},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]}],
#    'properties': {'system:index': '1'}}]}

# %%
# Merge two collections.
mergedCollection = collectionFromConstructor.merge(collectionFromImages)
print('mergedCollection: ')
mergedCollection.getInfo()
# Out:
# mergedCollection:
# {'type': 'ImageCollection',
#  'bands': [],
#  'features': [{'type': 'Image',
#    'bands': [{'id': 'constant',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 1,
#       'max': 1},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]}],
#    'properties': {'system:index': '1_0'}},
#   {'type': 'Image',
#    'bands': [{'id': 'constant',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 2,
#       'max': 2},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]}],
#    'properties': {'system:index': '1_1'}},
#   {'type': 'Image',
#    'bands': [{'id': 'constant',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 3,
#       'max': 3},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]}],
#    'properties': {'system:index': '2_0'}},
#   {'type': 'Image',
#    'bands': [{'id': 'constant',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 4,
#       'max': 4},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]}],
#    'properties': {'system:index': '2_1'}}]}

# %%
# Create a toy FeatureCollection
features = ee.FeatureCollection(
  [ee.Feature(None, {'foo': 1}), ee.Feature(None, {'foo': 2})])

# Create an ImageCollection from the FeatureCollection
# by mapping a function over the FeatureCollection.
images = features.map(lambda feature:ee.Image(ee.Number(feature.get('foo'))))

# Print the resultant collection.
print('Image collection: ')
images.getInfo()
# Out:
# Image collection:
# {'type': 'ImageCollection',
#  'bands': [],
#  'features': [{'type': 'Image',
#    'bands': [{'id': 'constant',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 1,
#       'max': 1},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]}],
#    'properties': {'system:index': '0'}},
#   {'type': 'Image',
#    'bands': [{'id': 'constant',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 2,
#       'max': 2},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]}],
#    'properties': {'system:index': '1'}}]}

# %% [markdown]
# Note that in this example an `ImageCollection` is created by mapping a function that returns an `Image` over a `FeatureCollection`. Learn more about mapping in the [Mapping over an ImageCollection section](https://developers.google.com/earth-engine/ic_mapping). Learn more about feature collections from the [FeatureCollection section](https://developers.google.com/earth-engine/feature_collections).

# %% [markdown]
# # 2. ImageCollection Information and Metadata
#
# As with Images, there are a variety of ways to get information about an ImageCollection. The collection can be printed directly to the console, but the console printout is **limited to 5000 elements**. Collections larger than 5000 images will need to be filtered before printing. Printing a large collection will be correspondingly slower. The following example shows various ways of getting information about image collections programmatically.

# %%
# Load Sentinel-5P NO2 imagery for a single Latitude/Longitude
collection = ee.ImageCollection('COPERNICUS/S2_SR')\
               .filterBounds(ee.Geometry.Point(coords=[33.5731, -7.5898]))\
               .filterDate('2019-01-01', '2019-12-01')
print('Collection: ')
# collection.getInfo()
# Out:
# Collection:

# %%
# Get the number of images.
count = collection.size()
print('Count: ', count.getInfo())
# Out:
# Count:  69

# %%
from datetime import datetime as dt
# Get the date range of images in the collection.
rango = collection.reduceColumns(ee.Reducer.minMax(), ["system:time_start"])

# Passing numeric date to standard
init_date = ee.Date(rango.get('min')).getInfo()['value']/1000.
init_date_f = dt.utcfromtimestamp(init_date).strftime('%Y-%m-%d %H:%M:%S')

last_date = ee.Date(rango.get('max')).getInfo()['value']/1000.
last_date_f = dt.utcfromtimestamp(last_date).strftime('%Y-%m-%d %H:%M:%S')

print('Date range: ',init_date_f,' - ',last_date_f)
# Out:
# Date range:  2019-01-02 08:12:08  -  2019-11-28 08:12:13

# %%
collection.propertyNames().getInfo()
# Out:
# ['date_range',
#  'period',
#  'system:visualization_0_min',
#  'type_name',
#  'system:visualization_0_bands',
#  'thumb',
#  'description',
#  'source_tags',
#  'system:id',
#  'visualization_0_max',
#  'provider_url',
#  'title',
#  'sample',
#  'tags',
#  'system:visualization_0_max',
#  'product_tags',
#  'provider',
#  'visualization_0_min',
#  'system:version',
#  'system:visualization_0_name',
#  'visualization_0_name',
#  'visualization_0_bands']

# %%
# Get statistics for a property of the images in the collection.
sunStats = collection.aggregate_stats('WATER_PERCENTAGE')
print('Sun elevation statistics: ')
sunStats.getInfo()
# Out:
# Sun elevation statistics:
# {'type': 'DataDictionary',
#  'values': {'max': 0.044303,
#   'mean': 0.0016836521739130431,
#   'min': 0,
#   'sample_sd': 0.005742575208414486,
#   'sample_var': 3.297717002429668e-05,
#   'sum': 0.11617199999999998,
#   'sum_sq': 0.002438040802,
#   'total_count': 69,
#   'total_sd': 0.005700810470796636,
#   'total_var': 3.2499240023944556e-05,
#   'valid_count': 69,
#   'weight_sum': 69,
#   'weighted_sum': 0.11617199999999998}}

# %%
# Sort by a cloud cover property, get the least cloudy image.
image = ee.Image(collection.sort('CLOUDY_PIXEL_PERCENTAGE').first())
print('Least cloudy image: ', )
image.getInfo()
# Out:
# Least cloudy image:
# {'type': 'Image',
#  'bands': [{'id': 'B1',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32736',
#    'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#   {'id': 'B2',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32736',
#    'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#   {'id': 'B3',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32736',
#    'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#   {'id': 'B4',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32736',
#    'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#   {'id': 'B5',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32736',
#    'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#   {'id': 'B6',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32736',
#    'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#   {'id': 'B7',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32736',
#    'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#   {'id': 'B8',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32736',
#    'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#   {'id': 'B8A',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32736',
#    'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#   {'id': 'B9',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32736',
#    'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#   {'id': 'B11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32736',
#    'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#   {'id': 'B12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32736',
#    'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#   {'id': 'AOT',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32736',
#    'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#   {'id': 'WVP',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32736',
#    'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#   {'id': 'SCL',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32736',
#    'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#   {'id': 'TCI_R',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32736',
#    'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#   {'id': 'TCI_G',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32736',
#    'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#   {'id': 'TCI_B',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32736',
#    'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#   {'id': 'MSK_CLDPRB',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32736',
#    'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#   {'id': 'MSK_SNWPRB',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32736',
#    'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#   {'id': 'QA10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32736',
#    'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#   {'id': 'QA20',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 4294967295},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32736',
#    'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#   {'id': 'QA60',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32736',
#    'crs_transform': [60, 0, 499980, 0, -60, 9200020]}],
#  'id': 'COPERNICUS/S2_SR/20190611T074611_20190611T080836_T36MWS',
#  'version': 1560716329717833,
#  'properties': {'DATATAKE_IDENTIFIER': 'GS2A_20190611T074611_020724_N02.12',
#   'AOT_RETRIEVAL_ACCURACY': 0,
#   'SPACECRAFT_NAME': 'Sentinel-2A',
#   'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 207.510164682,
#   'CLOUD_SHADOW_PERCENTAGE': 0,
#   'MEAN_SOLAR_AZIMUTH_ANGLE': 35.9692978646,
#   'system:footprint': {'type': 'LinearRing',
#    'coordinates': [[32.999807075127826, -8.230407264209894],
#     [32.99981841737743, -8.230407948558401],
#     [33.99653056706293, -8.22917202233163],
#     [33.99657231784664, -8.229135372984585],
#     [33.99661849027974, -8.229104148766677],
#     [33.99662129633845, -8.229089404512614],
#     [33.995419104868745, -7.732646457111067],
#     [33.99429402367819, -7.236199348935744],
#     [33.99425703377347, -7.236158002738269],
#     [33.99422557108411, -7.236112333569059],
#     [33.9942106900786, -7.2361095900412895],
#     [32.99981884700807, -7.23719471917643],
#     [32.999777000974895, -7.237231256802381],
#     [32.99973094454023, -7.2372624001526455],
#     [32.999728108975454, -7.237277147404122],
#     [32.999727507492004, -8.230317965582355],
#     [32.999764455754125, -8.230359419955635],
#     [32.99979581880308, -8.23040513202329],
#     [32.999807075127826, -8.230407264209894]]},
#   'VEGETATION_PERCENTAGE': 87.278885,
#   'SOLAR_IRRADIANCE_B12': 85.25,
#   'SOLAR_IRRADIANCE_B10': 367.15,
#   'SENSOR_QUALITY': 'PASSED',
#   'SOLAR_IRRADIANCE_B11': 245.59,
#   'GENERATION_TIME': 1560251459000,
#   'SOLAR_IRRADIANCE_B8A': 955.32,
#   'FORMAT_CORRECTNESS': 'PASSED',
#   'CLOUD_COVERAGE_ASSESSMENT': 8e-05,
#   'THIN_CIRRUS_PERCENTAGE': 3.3e-05,
#   'system:time_end': 1560240736000,
#   'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#   'system:time_start': 1560240736000,
#   'DATASTRIP_ID': 'S2A_OPER_MSI_L2A_DS_MTI__20190611T111059_S20190611T080836_N02.12',
#   'PROCESSING_BASELINE': '02.12',
#   'SENSING_ORBIT_NUMBER': 135,
#   'NODATA_PIXEL_PERCENTAGE': 0,
#   'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#   'GENERAL_QUALITY': 'PASSED',
#   'GRANULE_ID': 'L2A_T36MWS_A020724_20190611T080836',
#   'REFLECTANCE_CONVERSION_CORRECTION': 0.970898468956,
#   'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 1e-05,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 212.181429964,
#   'DATATAKE_TYPE': 'INS-NOBS',
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 206.685274067,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 208.309634248,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 207.867178373,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 209.473102703,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.36077863289,
#   'NOT_VEGETATED_PERCENTAGE': 12.645479,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 208.828068808,
#   'RADIOMETRIC_QUALITY': 'PASSED',
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 214.006963715,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 211.275187227,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.03265782405,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 207.167401837,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 2.96088533918,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 2.8431743661,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 2.74683159071,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 3.45444670049,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 2.78562866156,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.18905359648,
#   'DARK_FEATURES_PERCENTAGE': 0.059844,
#   'HIGH_PROBA_CLOUDS_PERCENTAGE': 3.6e-05,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.10869683807,
#   'UNCLASSIFIED_PERCENTAGE': 0.015521,
#   'MEAN_SOLAR_ZENITH_ANGLE': 38.3376864264,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.27275711284,
#   'RADIATIVE_TRANSFER_ACCURACY': 0,
#   'MGRS_TILE': '36MWS',
#   'CLOUDY_PIXEL_PERCENTAGE': 8e-05,
#   'PRODUCT_ID': 'S2A_MSIL2A_20190611T074611_N0212_R135_T36MWS_20190611T111059',
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 2.94792662562,
#   'SOLAR_IRRADIANCE_B9': 812.92,
#   'SNOW_ICE_PERCENTAGE': 0,
#   'DEGRADED_MSI_DATA_PERCENTAGE': 0,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.11329047631,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.30311681688,
#   'SOLAR_IRRADIANCE_B6': 1287.61,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 209.754564624,
#   'SOLAR_IRRADIANCE_B5': 1424.64,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 207.617389733,
#   'SOLAR_IRRADIANCE_B8': 1041.63,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 206.547791465,
#   'SOLAR_IRRADIANCE_B7': 1162.08,
#   'SOLAR_IRRADIANCE_B2': 1959.72,
#   'SOLAR_IRRADIANCE_B1': 1884.69,
#   'SOLAR_IRRADIANCE_B4': 1512.06,
#   'GEOMETRIC_QUALITY': 'PASSED',
#   'SOLAR_IRRADIANCE_B3': 1823.24,
#   'system:asset_size': 1660201303,
#   'WATER_PERCENTAGE': 0.000192,
#   'system:index': '20190611T074611_20190611T080836_T36MWS'}}

# %%
# Limit the collection to the 10 most recent images.
recent = collection.sort('system:time_start', False).limit(10)
print('Recent images: ')
recent.getInfo()
# Out:
# Recent images:
# {'type': 'ImageCollection',
#  'bands': [],
#  'id': 'COPERNICUS/S2_SR',
#  'version': 1576588623187418,
#  'properties': {'date_range': [1490659200000, 1576454400000],
#   'period': 0,
#   'system:visualization_0_min': '0.0',
#   'type_name': 'ImageCollection',
#   'system:visualization_0_bands': 'B4,B3,B2',
#   'thumb': 'https://mw1.google.com/ges/dd/images/COPERNICUS_S2_SR_thumb.png',
#   'description': '<p>Sentinel-2 is a wide-swath, high-resolution, multi-spectral\nimaging mission supporting Copernicus Land Monitoring studies,\nincluding the monitoring of vegetation, soil and water cover,\nas well as observation of inland waterways and coastal areas.</p><p>The Sentinel-2 L2 data are downloaded from scihub. They were\ncomputed by running sen2cor. WARNING: ESA did not produce L2 data\nfor all L1 assets, and earlier L2 coverage is not global.</p><p>The assets contain\n12 UINT16 spectral bands representing SR scaled by 10000 (unlike in L1 data,\nthere is no B10). There are also several more L2-specific bands (see band\nlist for details). See the\n<a href="https://sentinel.esa.int/documents/247904/685211/Sentinel-2_User_Handbook">Sentinel-2 User Handbook</a>\nfor details. In addition, three QA bands are present where one\n(QA60) is a bitmask band with cloud mask information. For more\ndetails, <a href="https://sentinel.esa.int/web/sentinel/technical-guides/sentinel-2-msi/level-1c/cloud-masks">see the full explanation of how cloud masks are computed.</a></p><p>EE asset ids for Sentinel-2 L2 assets have the following format:\nCOPERNICUS/S2_SR/20151128T002653_20151128T102149_T56MNN. Here the\nfirst numeric part represents the sensing date and time, the\nsecond numeric part represents the product generation date and\ntime, and the final 6-character string is a unique granule identifier\nindicating its UTM grid reference (see <a href="https://en.wikipedia.org/wiki/Military_Grid_Reference_System">MGRS</a>).</p><p>For more details on Sentinel-2 radiometric resolution, <a href="https://earth.esa.int/web/sentinel/user-guides/sentinel-2-msi/resolutions/radiometric">see this page</a>.</p><p><b>Revisit Interval</b><br>\n  5 days\n</p><p><b>Bands</b><table class="eecat"><tr><th scope="col">Name</th><th scope="col">Units</th><th scope="col">Min</th><th scope="col">Max</th><th scope="col">Scale</th><th scope="col">Resolution</th><th scope="col">Wavelength</th><th scope="col">Description</th></tr><tr><td>B1</td><td></td><td></td><td></td><td>0.0001</td><td>\n      60 meters\n</td><td>443.9nm (S2A) / 442.3nm (S2B)</td><td><p>Aerosols</p></td></tr><tr><td>B2</td><td></td><td></td><td></td><td>0.0001</td><td>\n      10 meters\n</td><td>496.6nm (S2A) / 492.1nm (S2B)</td><td><p>Blue</p></td></tr><tr><td>B3</td><td></td><td></td><td></td><td>0.0001</td><td>\n      10 meters\n</td><td>560nm (S2A) / 559nm (S2B)</td><td><p>Green</p></td></tr><tr><td>B4</td><td></td><td></td><td></td><td>0.0001</td><td>\n      10 meters\n</td><td>664.5nm (S2A) / 665nm (S2B)</td><td><p>Red</p></td></tr><tr><td>B5</td><td></td><td></td><td></td><td>0.0001</td><td>\n      20 meters\n</td><td>703.9nm (S2A) / 703.8nm (S2B)</td><td><p>Red Edge 1</p></td></tr><tr><td>B6</td><td></td><td></td><td></td><td>0.0001</td><td>\n      20 meters\n</td><td>740.2nm (S2A) / 739.1nm (S2B)</td><td><p>Red Edge 2</p></td></tr><tr><td>B7</td><td></td><td></td><td></td><td>0.0001</td><td>\n      20 meters\n</td><td>782.5nm (S2A) / 779.7nm (S2B)</td><td><p>Red Edge 3</p></td></tr><tr><td>B8</td><td></td><td></td><td></td><td>0.0001</td><td>\n      10 meters\n</td><td>835.1nm (S2A) / 833nm (S2B)</td><td><p>NIR</p></td></tr><tr><td>B8A</td><td></td><td></td><td></td><td>0.0001</td><td>\n      20 meters\n</td><td>864.8nm (S2A) / 864nm (S2B)</td><td><p>Red Edge 4</p></td></tr><tr><td>B9</td><td></td><td></td><td></td><td>0.0001</td><td>\n      60 meters\n</td><td>945nm (S2A) / 943.2nm (S2B)</td><td><p>Water vapor</p></td></tr><tr><td>B11</td><td></td><td></td><td></td><td>0.0001</td><td>\n      20 meters\n</td><td>1613.7nm (S2A) / 1610.4nm (S2B)</td><td><p>SWIR 1</p></td></tr><tr><td>B12</td><td></td><td></td><td></td><td>0.0001</td><td>\n      20 meters\n</td><td>2202.4nm (S2A) / 2185.7nm (S2B)</td><td><p>SWIR 2</p></td></tr><tr><td>AOT</td><td></td><td></td><td></td><td>0.001</td><td>\n      10 meters\n</td><td></td><td><p>Aerosol Optical Thickness</p></td></tr><tr><td>WVP</td><td> ...
#   'source_tags': ['eu', 'esa', 'copernicus', 'sentinel'],
#   'visualization_0_max': '3000.0',
#   'provider_url': 'https://earth.esa.int/web/sentinel/user-guides/sentinel-2-msi/product-types/level-2a',
#   'title': 'Sentinel-2 MSI: MultiSpectral Instrument, Level-2A',
#   'sample': 'https://mw1.google.com/ges/dd/images/COPERNICUS_S2_SR_sample.png',
#   'tags': ['eu', 'esa', 'copernicus', 'sentinel', 'msi', 'sr', 'reflectance'],
#   'system:visualization_0_max': '3000.0',
#   'product_tags': ['msi', 'sr', 'reflectance'],
#   'provider': 'European Union/ESA/Copernicus',
#   'visualization_0_min': '0.0',
#   'system:visualization_0_name': 'RGB',
#   'visualization_0_name': 'RGB',
#   'visualization_0_bands': 'B4,B3,B2'},
#  'features': [{'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B9',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'AOT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'WVP',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'SCL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'TCI_R',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'TCI_G',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'TCI_B',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'MSK_CLDPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'MSK_SNWPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]}],
#    'id': 'COPERNICUS/S2_SR/20191128T075251_20191128T075606_T36MWS',
#    'version': 1575056889527639,
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2A_20191128T075251_023155_N02.13',
#     'AOT_RETRIEVAL_ACCURACY': 0,
#     'SPACECRAFT_NAME': 'Sentinel-2A',
#     'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 208.013795585,
#     'CLOUD_SHADOW_PERCENTAGE': 0.791288,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 126.688986,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[32.999807075127826, -8.230407264209894],
#       [32.99981841737743, -8.230407948558401],
#       [33.99653056706293, -8.22917202233163],
#       [33.99657231784664, -8.229135372984585],
#       [33.99661849027974, -8.229104148766677],
#       [33.99662129633845, -8.229089404512614],
#       [33.995419104868745, -7.732646457111067],
#       [33.99429402367819, -7.236199348935744],
#       [33.99425703377347, -7.236158002738269],
#       [33.99422557108411, -7.236112333569059],
#       [33.9942106900786, -7.2361095900412895],
#       [32.99981884700807, -7.23719471917643],
#       [32.999777000974895, -7.237231256802381],
#       [32.99973094454023, -7.2372624001526455],
#       [32.999728108975454, -7.237277147404122],
#       [32.999727507492004, -8.230317965582355],
#       [32.999764455754125, -8.230359419955635],
#       [32.99979581880308, -8.23040513202329],
#       [32.999807075127826, -8.230407264209894]]},
#     'VEGETATION_PERCENTAGE': 11.804649,
#     'SOLAR_IRRADIANCE_B12': 85.25,
#     'SOLAR_IRRADIANCE_B10': 367.15,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 245.59,
#     'GENERATION_TIME': 1574938146000,
#     'SOLAR_IRRADIANCE_B8A': 955.32,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 76.782759,
#     'THIN_CIRRUS_PERCENTAGE': 10.227425,
#     'system:time_end': 1574928733597,
#     'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#     'system:time_start': 1574928733597,
#     'DATASTRIP_ID': 'S2A_OPER_MSI_L2A_DS_EPAE_20191128T104906_S20191128T075606_N02.13',
#     'PROCESSING_BASELINE': '02.13',
#     'SENSING_ORBIT_NUMBER': 135,
#     'NODATA_PIXEL_PERCENTAGE': 0,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L2A_T36MWS_A023155_20191128T075606',
#     'REFLECTANCE_CONVERSION_CORRECTION': 1.0262536737,
#     'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 24.227266,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 213.136010091,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 207.271534466,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 208.907960986,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 208.380787469,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 210.252885314,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.38403618192,
#     'NOT_VEGETATED_PERCENTAGE': 4.34772,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 209.595073557,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 214.575065671,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 211.983099482,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.05794464361,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 207.536929272,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 2.98647276971,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 2.87341406633,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 2.76793873517,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 3.47625856874,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 2.81731044464,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.21009809353,
#     'DARK_FEATURES_PERCENTAGE': 0.64387,
#     'HIGH_PROBA_CLOUDS_PERCENTAGE': 42.328069,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.12861932667,
#     'UNCLASSIFIED_PERCENTAGE': 5.629367,
#     'MEAN_SOLAR_ZENITH_ANGLE': 23.8841464282,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.29354512914,
#     'RADIATIVE_TRANSFER_ACCURACY': 0,
#     'MGRS_TILE': '36MWS',
#     'CLOUDY_PIXEL_PERCENTAGE': 76.782759,
#     'PRODUCT_ID': 'S2A_MSIL2A_20191128T075251_N0213_R135_T36MWS_20191128T104906',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 2.94585054401,
#     'SOLAR_IRRADIANCE_B9': 812.92,
#     'SNOW_ICE_PERCENTAGE': 0,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.11792631518,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.31284536457,
#     'SOLAR_IRRADIANCE_B6': 1287.61,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 210.694840042,
#     'SOLAR_IRRADIANCE_B5': 1424.64,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 209.19967122,
#     'SOLAR_IRRADIANCE_B8': 1041.63,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 208.228827783,
#     'SOLAR_IRRADIANCE_B7': 1162.08,
#     'SOLAR_IRRADIANCE_B2': 1959.72,
#     'SOLAR_IRRADIANCE_B1': 1884.69,
#     'SOLAR_IRRADIANCE_B4': 1512.06,
#     'GEOMETRIC_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B3': 1823.24,
#     'system:asset_size': 1576301375,
#     'WATER_PERCENTAGE': 0.000348,
#     'system:index': '20191128T075251_20191128T075606_T36MWS'}},
#   {'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B9',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'AOT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'WVP',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'SCL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'TCI_R',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'TCI_G',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'TCI_B',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'MSK_CLDPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'MSK_SNWPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]}],
#    'id': 'COPERNICUS/S2_SR/20191123T075229_20191123T080830_T36MWS',
#    'version': 1574626322398886,
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2B_20191123T075229_014175_N02.13',
#     'AOT_RETRIEVAL_ACCURACY': 0,
#     'SPACECRAFT_NAME': 'Sentinel-2B',
#     'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 206.148422024,
#     'CLOUD_SHADOW_PERCENTAGE': 0.143815,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 125.050107546,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[32.999807075127826, -8.230407264209894],
#       [32.99981841737743, -8.230407948558401],
#       [33.99653056706293, -8.22917202233163],
#       [33.99657231784664, -8.229135372984585],
#       [33.99661849027974, -8.229104148766677],
#       [33.99662129633845, -8.229089404512614],
#       [33.995419104868745, -7.732646457111067],
#       [33.99429402367819, -7.236199348935744],
#       [33.99425703377347, -7.236158002738269],
#       [33.99422557108411, -7.236112333569059],
#       [33.9942106900786, -7.2361095900412895],
#       [32.99981884700807, -7.23719471917643],
#       [32.999777000974895, -7.237231256802381],
#       [32.99973094454023, -7.2372624001526455],
#       [32.999728108975454, -7.237277147404122],
#       [32.999727507492004, -8.230317965582355],
#       [32.999764455754125, -8.230359419955635],
#       [32.99979581880308, -8.23040513202329],
#       [32.999807075127826, -8.230407264209894]]},
#     'VEGETATION_PERCENTAGE': 8.249903,
#     'SOLAR_IRRADIANCE_B12': 87.75,
#     'SOLAR_IRRADIANCE_B10': 365.41,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 247.08,
#     'GENERATION_TIME': 1574504684000,
#     'SOLAR_IRRADIANCE_B8A': 953.93,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 77.44147,
#     'THIN_CIRRUS_PERCENTAGE': 13.444155,
#     'system:time_end': 1574496731004,
#     'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#     'system:time_start': 1574496731004,
#     'DATASTRIP_ID': 'S2B_OPER_MSI_L2A_DS_SGS__20191123T102444_S20191123T080830_N02.13',
#     'PROCESSING_BASELINE': '02.13',
#     'SENSING_ORBIT_NUMBER': 135,
#     'NODATA_PIXEL_PERCENTAGE': 0,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L2A_T36MWS_A014175_20191123T080830',
#     'REFLECTANCE_CONVERSION_CORRECTION': 1.02424937853,
#     'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 11.173645,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 210.812852206,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 205.782299269,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 207.045878512,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 206.641196428,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 208.216616828,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.3683916838,
#     'NOT_VEGETATED_PERCENTAGE': 8.100627,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 207.530073059,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 212.191169686,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 209.711431686,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.04293773582,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 206.189255041,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 2.97021584445,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 2.85175752232,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 2.74590978097,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 3.45610513691,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 2.79547283688,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.19885388316,
#     'DARK_FEATURES_PERCENTAGE': 0.966709,
#     'HIGH_PROBA_CLOUDS_PERCENTAGE': 52.823669,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.11888698478,
#     'UNCLASSIFIED_PERCENTAGE': 5.097352,
#     'MEAN_SOLAR_ZENITH_ANGLE': 23.0889517276,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.27748623251,
#     'RADIATIVE_TRANSFER_ACCURACY': 0,
#     'MGRS_TILE': '36MWS',
#     'CLOUDY_PIXEL_PERCENTAGE': 77.44147,
#     'PRODUCT_ID': 'S2B_MSIL2A_20191123T075229_N0213_R135_T36MWS_20191123T102444',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 2.93520001102,
#     'SOLAR_IRRADIANCE_B9': 817.58,
#     'SNOW_ICE_PERCENTAGE': 0,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.10603644615,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.29608076555,
#     'SOLAR_IRRADIANCE_B6': 1291.13,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 208.448159196,
#     'SOLAR_IRRADIANCE_B5': 1425.78,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 207.140242495,
#     'SOLAR_IRRADIANCE_B8': 1041.28,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 206.099023498,
#     'SOLAR_IRRADIANCE_B7': 1175.57,
#     'SOLAR_IRRADIANCE_B2': 1959.77,
#     'SOLAR_IRRADIANCE_B1': 1874.3,
#     'SOLAR_IRRADIANCE_B4': 1512.79,
#     'GEOMETRIC_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B3': 1824.93,
#     'system:asset_size': 1613137871,
#     'WATER_PERCENTAGE': 0.000123,
#     'system:index': '20191123T075229_20191123T080830_T36MWS'}},
#   {'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B9',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'AOT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'WVP',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'SCL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'TCI_R',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'TCI_G',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'TCI_B',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'MSK_CLDPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'MSK_SNWPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]}],
#    'id': 'COPERNICUS/S2_SR/20191118T075211_20191118T080759_T36MWS',
#    'version': 1574194401001821,
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2A_20191118T075211_023012_N02.13',
#     'AOT_RETRIEVAL_ACCURACY': 0,
#     'SPACECRAFT_NAME': 'Sentinel-2A',
#     'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 208.759142312,
#     'CLOUD_SHADOW_PERCENTAGE': 0.265573,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 122.886555845,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[32.999807075127826, -8.230407264209894],
#       [32.99981841737743, -8.230407948558401],
#       [33.99653056706293, -8.22917202233163],
#       [33.99657231784664, -8.229135372984585],
#       [33.99661849027974, -8.229104148766677],
#       [33.99662129633845, -8.229089404512614],
#       [33.995419104868745, -7.732646457111067],
#       [33.99429402367819, -7.236199348935744],
#       [33.99425703377347, -7.236158002738269],
#       [33.99422557108411, -7.236112333569059],
#       [33.9942106900786, -7.2361095900412895],
#       [32.99981884700807, -7.23719471917643],
#       [32.999777000974895, -7.237231256802381],
#       [32.99973094454023, -7.2372624001526455],
#       [32.999728108975454, -7.237277147404122],
#       [32.999727507492004, -8.230317965582355],
#       [32.999764455754125, -8.230359419955635],
#       [32.99979581880308, -8.23040513202329],
#       [32.999807075127826, -8.230407264209894]]},
#     'VEGETATION_PERCENTAGE': 3.182066,
#     'SOLAR_IRRADIANCE_B12': 85.25,
#     'SOLAR_IRRADIANCE_B10': 367.15,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 245.59,
#     'GENERATION_TIME': 1574073007000,
#     'SOLAR_IRRADIANCE_B8A': 955.32,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 87.490913,
#     'THIN_CIRRUS_PERCENTAGE': 4.069436,
#     'system:time_end': 1574064735442,
#     'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#     'system:time_start': 1574064735442,
#     'DATASTRIP_ID': 'S2A_OPER_MSI_L2A_DS_SGS__20191118T103007_S20191118T080759_N02.13',
#     'PROCESSING_BASELINE': '02.13',
#     'SENSING_ORBIT_NUMBER': 135,
#     'NODATA_PIXEL_PERCENTAGE': 0,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L2A_T36MWS_A023012_20191118T080759',
#     'REFLECTANCE_CONVERSION_CORRECTION': 1.02206902517,
#     'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 38.076174,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 213.581909202,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 208.117113306,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 209.596797328,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 209.1344855,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 210.803454764,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.39380131462,
#     'NOT_VEGETATED_PERCENTAGE': 4.809105,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 210.135957672,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 215.040717505,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 212.411686211,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.06697823053,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 208.39717634,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 2.99546775117,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 2.87700425874,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 2.7712421808,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 3.48594259037,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 2.82076039027,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.22278574055,
#     'DARK_FEATURES_PERCENTAGE': 0.402802,
#     'HIGH_PROBA_CLOUDS_PERCENTAGE': 45.345303,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.14273782587,
#     'UNCLASSIFIED_PERCENTAGE': 3.84945,
#     'MEAN_SOLAR_ZENITH_ANGLE': 22.2786540858,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.3061671206,
#     'RADIATIVE_TRANSFER_ACCURACY': 0,
#     'MGRS_TILE': '36MWS',
#     'CLOUDY_PIXEL_PERCENTAGE': 87.490913,
#     'PRODUCT_ID': 'S2A_MSIL2A_20191118T075211_N0213_R135_T36MWS_20191118T103007',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 2.97132708067,
#     'SOLAR_IRRADIANCE_B9': 812.92,
#     'SNOW_ICE_PERCENTAGE': 0,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.14616770226,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.34010384231,
#     'SOLAR_IRRADIANCE_B6': 1287.61,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 211.358135756,
#     'SOLAR_IRRADIANCE_B5': 1424.64,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 209.799682236,
#     'SOLAR_IRRADIANCE_B8': 1041.63,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 208.806950935,
#     'SOLAR_IRRADIANCE_B7': 1162.08,
#     'SOLAR_IRRADIANCE_B2': 1959.72,
#     'SOLAR_IRRADIANCE_B1': 1884.69,
#     'SOLAR_IRRADIANCE_B4': 1512.06,
#     'GEOMETRIC_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B3': 1823.24,
#     'system:asset_size': 1445535362,
#     'WATER_PERCENTAGE': 9e-05,
#     'system:index': '20191118T075211_20191118T080759_T36MWS'}},
#   {'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B9',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'AOT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'WVP',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'SCL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'TCI_R',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'TCI_G',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'TCI_B',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'MSK_CLDPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'MSK_SNWPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]}],
#    'id': 'COPERNICUS/S2_SR/20191113T075059_20191113T080912_T36MWS',
#    'version': 1573779690996131,
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2B_20191113T075059_014032_N02.13',
#     'AOT_RETRIEVAL_ACCURACY': 0,
#     'SPACECRAFT_NAME': 'Sentinel-2B',
#     'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 206.995116513,
#     'CLOUD_SHADOW_PERCENTAGE': 0.041188,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 120.095398175,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[32.999807075127826, -8.230407264209894],
#       [32.99981841737743, -8.230407948558401],
#       [33.99653056706293, -8.22917202233163],
#       [33.99657231784664, -8.229135372984585],
#       [33.99661849027974, -8.229104148766677],
#       [33.99662129633845, -8.229089404512614],
#       [33.995419104868745, -7.732646457111067],
#       [33.99429402367819, -7.236199348935744],
#       [33.99425703377347, -7.236158002738269],
#       [33.99422557108411, -7.236112333569059],
#       [33.9942106900786, -7.2361095900412895],
#       [32.99981884700807, -7.23719471917643],
#       [32.999777000974895, -7.237231256802381],
#       [32.99973094454023, -7.2372624001526455],
#       [32.999728108975454, -7.237277147404122],
#       [32.999727507492004, -8.230317965582355],
#       [32.999764455754125, -8.230359419955635],
#       [32.99979581880308, -8.23040513202329],
#       [32.999807075127826, -8.230407264209894]]},
#     'VEGETATION_PERCENTAGE': 63.651586,
#     'SOLAR_IRRADIANCE_B12': 87.75,
#     'SOLAR_IRRADIANCE_B10': 365.41,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 247.08,
#     'GENERATION_TIME': 1573643177000,
#     'SOLAR_IRRADIANCE_B8A': 953.93,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 3.164133,
#     'THIN_CIRRUS_PERCENTAGE': 3.069038,
#     'system:time_end': 1573632733019,
#     'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#     'system:time_start': 1573632733019,
#     'DATASTRIP_ID': 'S2B_OPER_MSI_L2A_DS_MTI__20191113T110617_S20191113T080912_N02.13',
#     'PROCESSING_BASELINE': '02.13',
#     'SENSING_ORBIT_NUMBER': 135,
#     'NODATA_PIXEL_PERCENTAGE': 0,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L2A_T36MWS_A014032_20191113T080912',
#     'REFLECTANCE_CONVERSION_CORRECTION': 1.01973004794,
#     'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 0.037074,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 211.526735496,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 206.425486578,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 207.760995075,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 207.339041156,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 208.886593975,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.3651464648,
#     'NOT_VEGETATED_PERCENTAGE': 33.024442,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 208.262983123,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 212.921260204,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 210.409363239,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.03671056595,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 206.672984457,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 2.96495983792,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 2.84603597087,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 2.7396729526,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 3.45788826239,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 2.78949482228,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.19310619759,
#     'DARK_FEATURES_PERCENTAGE': 0.08561,
#     'HIGH_PROBA_CLOUDS_PERCENTAGE': 0.058022,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.1129010759,
#     'UNCLASSIFIED_PERCENTAGE': 0.03291,
#     'MEAN_SOLAR_ZENITH_ANGLE': 21.5333532112,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.27689125215,
#     'RADIATIVE_TRANSFER_ACCURACY': 0,
#     'MGRS_TILE': '36MWS',
#     'CLOUDY_PIXEL_PERCENTAGE': 3.164133,
#     'PRODUCT_ID': 'S2B_MSIL2A_20191113T075059_N0213_R135_T36MWS_20191113T110617',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 2.92860967699,
#     'SOLAR_IRRADIANCE_B9': 817.58,
#     'SNOW_ICE_PERCENTAGE': 0,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.10122701084,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.29670985976,
#     'SOLAR_IRRADIANCE_B6': 1291.13,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 209.20776125,
#     'SOLAR_IRRADIANCE_B5': 1425.78,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 207.782564371,
#     'SOLAR_IRRADIANCE_B8': 1041.28,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 206.876255992,
#     'SOLAR_IRRADIANCE_B7': 1175.57,
#     'SOLAR_IRRADIANCE_B2': 1959.77,
#     'SOLAR_IRRADIANCE_B1': 1874.3,
#     'SOLAR_IRRADIANCE_B4': 1512.79,
#     'GEOMETRIC_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B3': 1824.93,
#     'system:asset_size': 1748377359,
#     'WATER_PERCENTAGE': 0.000133,
#     'system:index': '20191113T075059_20191113T080912_T36MWS'}},
#   {'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
# ...
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'MSK_SNWPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]}],
#    'id': 'COPERNICUS/S2_SR/20191019T074931_20191019T080150_T36MWS',
#    'version': 1571791502778014,
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2A_20191019T074931_022583_N02.13',
#     'AOT_RETRIEVAL_ACCURACY': 0,
#     'SPACECRAFT_NAME': 'Sentinel-2A',
#     'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 209.694827408,
#     'CLOUD_SHADOW_PERCENTAGE': 0.544547,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 97.8542852526,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[32.999807075127826, -8.230407264209894],
#       [32.99981841737743, -8.230407948558401],
#       [33.99653056706293, -8.22917202233163],
#       [33.99657231784664, -8.229135372984585],
#       [33.99661849027974, -8.229104148766677],
#       [33.99662129633845, -8.229089404512614],
#       [33.995419104868745, -7.732646457111067],
#       [33.99429402367819, -7.236199348935744],
#       [33.99425703377347, -7.236158002738269],
#       [33.99422557108411, -7.236112333569059],
#       [33.9942106900786, -7.2361095900412895],
#       [32.99981884700807, -7.23719471917643],
#       [32.999777000974895, -7.237231256802381],
#       [32.99973094454023, -7.2372624001526455],
#       [32.999728108975454, -7.237277147404122],
#       [32.999727507492004, -8.230317965582355],
#       [32.999764455754125, -8.230359419955635],
#       [32.99979581880308, -8.23040513202329],
#       [32.999807075127826, -8.230407264209894]]},
#     'VEGETATION_PERCENTAGE': 11.314043,
#     'SOLAR_IRRADIANCE_B12': 85.25,
#     'SOLAR_IRRADIANCE_B10': 367.15,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 245.59,
#     'GENERATION_TIME': 1571481360000,
#     'SOLAR_IRRADIANCE_B8A': 955.32,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 55.747245,
#     'THIN_CIRRUS_PERCENTAGE': 1.170172,
#     'system:time_end': 1571472737221,
#     'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#     'system:time_start': 1571472737221,
#     'DATASTRIP_ID': 'S2A_OPER_MSI_L2A_DS_SGS__20191019T103600_S20191019T080150_N02.13',
#     'PROCESSING_BASELINE': '02.13',
#     'SENSING_ORBIT_NUMBER': 135,
#     'NODATA_PIXEL_PERCENTAGE': 0,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L2A_T36MWS_A022583_20191019T080150',
#     'REFLECTANCE_CONVERSION_CORRECTION': 1.00635038751,
#     'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 7.701703,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 214.530746726,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 209.048665625,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 210.536372148,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 210.072048074,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 211.747119332,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.40805923554,
#     'NOT_VEGETATED_PERCENTAGE': 22.889502,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 211.077538931,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 215.990460649,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 213.358900165,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.08147909812,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 209.330536599,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 3.01000506315,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 2.89158362168,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 2.78581803625,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 3.5001174794,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 2.83534382587,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.23718010869,
#     'DARK_FEATURES_PERCENTAGE': 1.735834,
#     'HIGH_PROBA_CLOUDS_PERCENTAGE': 46.87537,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.15718797193,
#     'UNCLASSIFIED_PERCENTAGE': 7.766116,
#     'MEAN_SOLAR_ZENITH_ANGLE': 19.5708836435,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.32049435529,
#     'RADIATIVE_TRANSFER_ACCURACY': 0,
#     'MGRS_TILE': '36MWS',
#     'CLOUDY_PIXEL_PERCENTAGE': 55.747245,
#     'PRODUCT_ID': 'S2A_MSIL2A_20191019T074931_N0213_R135_T36MWS_20191019T103600',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 2.99069023816,
#     'SOLAR_IRRADIANCE_B9': 812.92,
#     'SNOW_ICE_PERCENTAGE': 0,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.16073194343,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.35479054856,
#     'SOLAR_IRRADIANCE_B6': 1287.61,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 211.758429855,
#     'SOLAR_IRRADIANCE_B5': 1424.64,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 210.077869045,
#     'SOLAR_IRRADIANCE_B8': 1041.63,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 209.129840653,
#     'SOLAR_IRRADIANCE_B7': 1162.08,
#     'SOLAR_IRRADIANCE_B2': 1959.72,
#     'SOLAR_IRRADIANCE_B1': 1884.69,
#     'SOLAR_IRRADIANCE_B4': 1512.06,
#     'GEOMETRIC_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B3': 1823.24,
#     'system:asset_size': 1684519617,
#     'WATER_PERCENTAGE': 0.002714,
#     'system:index': '20191019T074931_20191019T080150_T36MWS'}},
#   {'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B9',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'AOT',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'WVP',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'SCL',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'TCI_R',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'TCI_G',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'TCI_B',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'MSK_CLDPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'MSK_SNWPRB',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32736',
#      'crs_transform': [10, 0, 499980, 0, -10, 9200020]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32736',
#      'crs_transform': [20, 0, 499980, 0, -20, 9200020]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32736',
#      'crs_transform': [60, 0, 499980, 0, -60, 9200020]}],
#    'id': 'COPERNICUS/S2_SR/20191014T074859_20191014T080733_T36MWS',
#    'version': 1571304227270437,
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2B_20191014T074859_013603_N02.13',
#     'AOT_RETRIEVAL_ACCURACY': 0,
#     'SPACECRAFT_NAME': 'Sentinel-2B',
#     'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 207.893735646,
#     'CLOUD_SHADOW_PERCENTAGE': 0.275533,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 92.3750456125,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[32.999807075127826, -8.230407264209894],
#       [32.99981841737743, -8.230407948558401],
#       [33.99653056706293, -8.22917202233163],
#       [33.99657231784664, -8.229135372984585],
#       [33.99661849027974, -8.229104148766677],
#       [33.99662129633845, -8.229089404512614],
#       [33.995419104868745, -7.732646457111067],
#       [33.99429402367819, -7.236199348935744],
#       [33.99425703377347, -7.236158002738269],
#       [33.99422557108411, -7.236112333569059],
#       [33.9942106900786, -7.2361095900412895],
#       [32.99981884700807, -7.23719471917643],
#       [32.999777000974895, -7.237231256802381],
#       [32.99973094454023, -7.2372624001526455],
#       [32.999728108975454, -7.237277147404122],
#       [32.999727507492004, -8.230317965582355],
#       [32.999764455754125, -8.230359419955635],
#       [32.99979581880308, -8.23040513202329],
#       [32.999807075127826, -8.230407264209894]]},
#     'VEGETATION_PERCENTAGE': 45.56866,
#     'SOLAR_IRRADIANCE_B12': 87.75,
#     'SOLAR_IRRADIANCE_B10': 365.41,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 247.08,
#     'GENERATION_TIME': 1571053271000,
#     'SOLAR_IRRADIANCE_B8A': 953.93,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 3.353874,
#     'THIN_CIRRUS_PERCENTAGE': 1.235318,
#     'system:time_end': 1571040735229,
#     'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#     'system:time_start': 1571040735229,
#     'DATASTRIP_ID': 'S2B_OPER_MSI_L2A_DS_EPAE_20191014T114111_S20191014T080733_N02.13',
#     'PROCESSING_BASELINE': '02.13',
#     'SENSING_ORBIT_NUMBER': 135,
#     'NODATA_PIXEL_PERCENTAGE': 0,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L2A_T36MWS_A013603_20191014T080733',
#     'REFLECTANCE_CONVERSION_CORRECTION': 1.00348352967,
#     'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 0.73726,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 212.056878896,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 207.622751198,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 208.635847778,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 208.225881514,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 209.579140151,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.3913050693,
#     'NOT_VEGETATED_PERCENTAGE': 48.712555,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 208.963333432,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 213.453984114,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 210.939611517,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.06207697571,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 207.689442812,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 2.99076852719,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 2.87053537443,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 2.76492677968,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 3.48521497807,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 2.81437249935,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.21943147474,
#     'DARK_FEATURES_PERCENTAGE': 1.169233,
#     'HIGH_PROBA_CLOUDS_PERCENTAGE': 1.381296,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.13972659082,
#     'UNCLASSIFIED_PERCENTAGE': 0.918876,
#     'MEAN_SOLAR_ZENITH_ANGLE': 19.7709198165,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.30271845146,
#     'RADIATIVE_TRANSFER_ACCURACY': 0,
#     'MGRS_TILE': '36MWS',
#     'CLOUDY_PIXEL_PERCENTAGE': 3.353874,
#     'PRODUCT_ID': 'S2B_MSIL2A_20191014T074859_N0213_R135_T36MWS_20191014T114111',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 2.95762307078,
#     'SOLAR_IRRADIANCE_B9': 817.58,
#     'SNOW_ICE_PERCENTAGE': 0,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.12494914966,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.31949908382,
#     'SOLAR_IRRADIANCE_B6': 1291.13,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 210.242975224,
#     'SOLAR_IRRADIANCE_B5': 1425.78,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 208.300472594,
#     'SOLAR_IRRADIANCE_B8': 1041.28,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 207.425212156,
#     'SOLAR_IRRADIANCE_B7': 1175.57,
#     'SOLAR_IRRADIANCE_B2': 1959.77,
#     'SOLAR_IRRADIANCE_B1': 1874.3,
#     'SOLAR_IRRADIANCE_B4': 1512.79,
#     'GEOMETRIC_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B3': 1824.93,
#     'system:asset_size': 1776206858,
#     'WATER_PERCENTAGE': 0.001267,
#     'system:index': '20191014T074859_20191014T080733_T36MWS'}}]}

# %% [markdown]
# # 3. Filtering an ImageCollection
#
# As illustrated in the Get Started section and the ImageCollection Information section, Earth Engine provides a variety of convenience methods for filtering image collections. Specifically, many common use cases are handled by **imageCollection.filterDate()**, and **imageCollection.filterBounds()**. For general purpose filtering, use **imageCollection.filter()** with an **ee.Filter** as an argument. The following example demonstrates both convenience methods and **filter()** to identify and remove images with bad registration from an **ImageCollection**.

# %%
# Load Landsat 5 data, filter by date and bounds.
collection = ee.ImageCollection('LANDSAT/LT05/C01/T2').filterDate('1987-01-01', '1990-05-01').filterBounds(ee.Geometry.Point(25.8544, -18.08874))

# Also filter the collection by the IMAGE_QUALITY property.
filtered = collection.filterMetadata('IMAGE_QUALITY', 'equals', 9)

# Create two composites to check the effect of filtering by IMAGE_QUALITY.
badComposite = ee.Algorithms.Landsat.simpleComposite(collection, 75, 3)
goodComposite = ee.Algorithms.Landsat.simpleComposite(filtered, 75, 3)

dicc = {
    'Bad composite' : badComposite.getMapId({'bands': ['B3', 'B2', 'B1'], 'gain': 3.5}),
    'Good composite': goodComposite.getMapId({'bands': ['B3', 'B2', 'B1'], 'gain': 3.5})
}

# Display the results
center = [-18.08874, 25.8544]
Mapdisplay(center, dicc, zoom_start= 13)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 4. Mapping over an ImageCollection
#
# To apply a function to every Image in an ImageCollection use imageCollection.map(). The only argument to map() is a function which takes one parameter: an ee.Image. For example, the following code adds a timestamp band to every image in the collection.

# %%
from pprint import pprint
# Load a Landsat 8 collection for a single path-row.
collection = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').filter(ee.Filter.eq('WRS_PATH', 44)).filter(ee.Filter.eq('WRS_ROW', 34))

# This function adds a band representing the image timestamp.
def addTime(image):
	return image.addBands(image.metadata('system:time_start'))

# Map the function over the collection and display the result.
pprint(collection.map(addTime).limit(3).getInfo())
# Out:
# {'bands': [],
#  'features': [{'bands': [{'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 494085, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7511, 7351],
#                           'id': 'B1'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 494085, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7511, 7351],
#                           'id': 'B2'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 494085, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7511, 7351],
#                           'id': 'B3'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 494085, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7511, 7351],
#                           'id': 'B4'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 494085, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7511, 7351],
#                           'id': 'B5'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 494085, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7511, 7351],
#                           'id': 'B6'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 494085, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7511, 7351],
#                           'id': 'B7'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [15, 0, 494092.5, 0, -15, 4257907.5],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [15021, 14701],
#                           'id': 'B8'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 494085, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7511, 7351],
#                           'id': 'B9'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 494085, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7511, 7351],
#                           'id': 'B10'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 494085, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7511, 7351],
#                           'id': 'B11'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 494085, 0, -30, 4257915],
#                           'data_type': {'max': 65535,
#                                         'min': 0,
#                                         'precision': 'int',
#                                         'type': 'PixelType'},
#                           'dimensions': [7511, 7351],
#                           'id': 'BQA'},
#                          {'crs': 'EPSG:4326',
#                           'crs_transform': [1, 0, 0, 0, 1, 0],
#                           'data_type': {'precision': 'double',
#                                         'type': 'PixelType'},
#                           'id': 'system:time_start'}],
#                'id': 'LANDSAT/LC08/C01/T1_TOA/LC08_044034_20130409',
#                'properties': {'BPF_NAME_OLI': 'LO8BPF20130409183627_20130409184813.01',
#                               'BPF_NAME_TIRS': 'LT8BPF20130409183233_20130409184905.01',
#                               'CLOUD_COVER': 0.05000000074505806,
#                               'CLOUD_COVER_LAND': 0.05999999865889549,
#                               'COLLECTION_CATEGORY': 'T1',
#                               'COLLECTION_NUMBER': 1,
#                               'CPF_NAME': 'LC08CPF_20130401_20130627_01.01',
#                               'DATA_TYPE': 'L1TP',
#                               'DATE_ACQUIRED': '2013-04-09',
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0017913579940796,
#                               'ELEVATION_SOURCE': 'GLS2000',
#                               'ELLIPSOID': 'WGS84',
#                               'FILE_DATE': 1489126619000,
#                               'GEOMETRIC_RMSE_MODEL': 6.677999973297119,
#                               'GEOMETRIC_RMSE_MODEL_X': 4.663000106811523,
#                               'GEOMETRIC_RMSE_MODEL_Y': 4.78000020980835,
#                               'GEOMETRIC_RMSE_VERIFY': 3.359999895095825,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 464,
#                               'GROUND_CONTROL_POINTS_VERIFY': 141,
#                               'GROUND_CONTROL_POINTS_VERSION': 4,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8853149414062,
#                               'K1_CONSTANT_BAND_11': 480.8883056640625,
#                               'K2_CONSTANT_BAND_10': 1321.078857421875,
#                               'K2_CONSTANT_BAND_11': 1201.1441650390625,
#                               'LANDSAT_PRODUCT_ID': 'LC08_L1TP_044034_20130409_20170310_01_T1',
#                               'LANDSAT_SCENE_ID': 'LC80440342013099LGN02',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'PANCHROMATIC_LINES': 14701,
#                               'PANCHROMATIC_SAMPLES': 15021,
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_2.7.0',
#                               'RADIANCE_ADD_BAND_1': -62.55445098876953,
#                               'RADIANCE_ADD_BAND_10': 0.10000000149011612,
#                               'RADIANCE_ADD_BAND_11': 0.10000000149011612,
#                               'RADIANCE_ADD_BAND_2': -64.0565185546875,
#                               'RADIANCE_ADD_BAND_3': -59.02753829956055,
#                               'RADIANCE_ADD_BAND_4': -49.77534103393555,
#                               'RADIANCE_ADD_BAND_5': -30.46002960205078,
#                               'RADIANCE_ADD_BAND_6': -7.575129985809326,
#                               'RADIANCE_ADD_BAND_7': -2.553230047225952,
#                               'RADIANCE_ADD_BAND_8': -56.33198928833008,
#                               'RADIANCE_ADD_BAND_9': -11.904470443725586,
#                               'RADIANCE_MULT_BAND_1': 0.012511000037193298,
#                               'RADIANCE_MULT_BAND_10': 0.00033420001273043454,
#                               'RADIANCE_MULT_BAND_11': 0.00033420001273043454,
#                               'RADIANCE_MULT_BAND_2': 0.01281100045889616,
#                               'RADIANCE_MULT_BAND_3': 0.011806000024080276,
#                               'RADIANCE_MULT_BAND_4': 0.009955099783837795,
#                               'RADIANCE_MULT_BAND_5': 0.00609199982136488,
#                               'RADIANCE_MULT_BAND_6': 0.0015150000108405948,
#                               'RADIANCE_MULT_BAND_7': 0.0005106499884277582,
#                               'RADIANCE_MULT_BAND_8': 0.011265999637544155,
#                               'RADIANCE_MULT_BAND_9': 0.0023809000849723816,
#                               'REFLECTANCE_ADD_BAND_1': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_2': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_3': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_4': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_5': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_6': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_7': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_8': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_9': -0.10000000149011612,
#                               'REFLECTANCE_MULT_BAND_1': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_2': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_3': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_4': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_5': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_6': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_7': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_8': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_9': 1.9999999494757503e-05,
#                               'REFLECTIVE_LINES': 7351,
#                               'REFLECTIVE_SAMPLES': 7511,
#                               'REQUEST_ID': '0501703096447_00024',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'RLUT_FILE_NAME': 'LC08RLUT_20130211_20150302_01_11.h5',
#                               'ROLL_ANGLE': -0.0010000000474974513,
#                               'SATURATION_BAND_1': 'Y',
#                               'SATURATION_BAND_2': 'Y',
#                               'SATURATION_BAND_3': 'Y',
#                               'SATURATION_BAND_4': 'Y',
#                               'SATURATION_BAND_5': 'Y',
#                               'SATURATION_BAND_6': 'Y',
#                               'SATURATION_BAND_7': 'Y',
#                               'SATURATION_BAND_8': 'N',
#                               'SATURATION_BAND_9': 'N',
#                               'SCENE_CENTER_TIME': '18:46:34.7579070Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 142.7425079345703,
#                               'SUN_ELEVATION': 55.02650451660156,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7351,
#                               'THERMAL_SAMPLES': 7511,
#                               'TIRS_SSM_MODEL': 'ACTUAL',
#                               'TIRS_SSM_POSITION_STATUS': 'NOMINAL',
#                               'TIRS_STRAY_LIGHT_CORRECTION_SOURCE': 'TIRS',
#                               'TRUNCATION_OLI': 'UPPER',
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'google:registration_count': 12,
#                               'google:registration_offset_x': 568.1591796875,
#                               'google:registration_offset_y': -55.98419189453125,
#                               'google:registration_ratio': 0.20338982343673706,
#                               'system:asset_size': 1107459784,
#                               'system:footprint': {'coordinates': [[-123.06358710510132,
#                                                                     36.8633609482674],
#                                                                    [-123.06272804832815,
#                                                                     36.86267156335577],
#                                                                    [-121.52760276705891,
#                                                                     36.5713194763866],
#                                                                    [-121.00459794482437,
#                                                                     36.467038618235456],
#                                                                    [-120.84546804784641,
#                                                                     36.978712048296025],
#                                                                    [-120.82569548685966,
#                                                                     37.04210637906386],
#                                                                    [-120.80618726938106,
#                                                                     37.10460923782187],
#                                                                    [-120.7792355850528,
#                                                                     37.19088142180353],
#                                                                    [-120.73958781436916,
#                                                                     37.317487881005604],
#                                                                    [-120.70922757600728,
#                                                                     37.41423289474712],
#                                                                    [-120.64144886779137,
#                                                                     37.629449412771955],
#                                                                    [-120.60743326010949,
#                                                                     37.737154542032904],
#                                                                    [-120.54865419358048,
#                                                                     37.923168487655346],
#                                                                    [-120.52001060194267,
#                                                                     38.013803490703864],
#                                                                    [-120.5027477474137,
#                                                                     38.06924150051513],
#                                                                    [-120.50267508434146,
#                                                                     38.07137597329512],
#                                                                    [-120.5379650531887,
#                                                                     38.07840852118765],
#                                                                    [-121.8766167779963,
#                                                                     38.335270752267164],
#                                                                    [-122.60513442672054,
#                                                                     38.46794398256013],
#                                                                    [-122.6095660966365,
#                                                                     38.45358105461426],
#                                                                    [-123.06358710510132,
#                                                                     36.8633609482674]],
#                                                    'type': 'LinearRing'},
#                               'system:index': 'LC08_044034_20130409',
#                               'system:time_start': 1365533194760},
#                'type': 'Image',
#                'version': 1576588724830660.0},
#               {'bands': [{'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B1'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B2'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B3'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B4'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B5'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B6'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B7'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [15, 0, 464992.5, 0, -15, 4257907.5],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [15141, 14741],
#                           'id': 'B8'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B9'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B10'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B11'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4257915],
#                           'data_type': {'max': 65535,
#                                         'min': 0,
#                                         'precision': 'int',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'BQA'},
#                          {'crs': 'EPSG:4326',
#                           'crs_transform': [1, 0, 0, 0, 1, 0],
#                           'data_type': {'precision': 'double',
#                                         'type': 'PixelType'},
#                           'id': 'system:time_start'}],
#                'id': 'LANDSAT/LC08/C01/T1_TOA/LC08_044034_20130416',
#                'properties': {'BPF_NAME_OLI': 'LO8BPF20130416183813_20130416184936.01',
#                               'BPF_NAME_TIRS': 'LT8BPF20130416183419_20130416185028.01',
#                               'CLOUD_COVER': 0.05999999865889549,
#                               'CLOUD_COVER_LAND': 0.07999999821186066,
#                               'COLLECTION_CATEGORY': 'T1',
#                               'COLLECTION_NUMBER': 1,
#                               'CPF_NAME': 'LC08CPF_20130401_20130627_01.01',
#                               'DATA_TYPE': 'L1TP',
#                               'DATE_ACQUIRED': '2013-04-16',
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0037447214126587,
#                               'ELEVATION_SOURCE': 'GLS2000',
#                               'ELLIPSOID': 'WGS84',
#                               'FILE_DATE': 1489146387000,
#                               'GEOMETRIC_RMSE_MODEL': 6.077000141143799,
#                               'GEOMETRIC_RMSE_MODEL_X': 4.224999904632568,
#                               'GEOMETRIC_RMSE_MODEL_Y': 4.368000030517578,
#                               'GEOMETRIC_RMSE_VERIFY': 3.6070001125335693,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 475,
#                               'GROUND_CONTROL_POINTS_VERIFY': 168,
#                               'GROUND_CONTROL_POINTS_VERSION': 4,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8853149414062,
#                               'K1_CONSTANT_BAND_11': 480.8883056640625,
#                               'K2_CONSTANT_BAND_10': 1321.078857421875,
#                               'K2_CONSTANT_BAND_11': 1201.1441650390625,
#                               'LANDSAT_PRODUCT_ID': 'LC08_L1TP_044034_20130416_20170310_01_T1',
#                               'LANDSAT_SCENE_ID': 'LC80440342013106LGN03',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'PANCHROMATIC_LINES': 14741,
#                               'PANCHROMATIC_SAMPLES': 15141,
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_2.7.0',
#                               'RADIANCE_ADD_BAND_1': -62.31122970581055,
#                               'RADIANCE_ADD_BAND_10': 0.10000000149011612,
#                               'RADIANCE_ADD_BAND_11': 0.10000000149011612,
#                               'RADIANCE_ADD_BAND_2': -63.80746078491211,
#                               'RADIANCE_ADD_BAND_3': -58.798030853271484,
#                               'RADIANCE_ADD_BAND_4': -49.581809997558594,
#                               'RADIANCE_ADD_BAND_5': -30.34160041809082,
#                               'RADIANCE_ADD_BAND_6': -7.545680046081543,
#                               'RADIANCE_ADD_BAND_7': -2.543299913406372,
#                               'RADIANCE_ADD_BAND_8': -56.11296081542969,
#                               'RADIANCE_ADD_BAND_9': -11.858180046081543,
#                               'RADIANCE_MULT_BAND_1': 0.012462000362575054,
#                               'RADIANCE_MULT_BAND_10': 0.00033420001273043454,
#                               'RADIANCE_MULT_BAND_11': 0.00033420001273043454,
#                               'RADIANCE_MULT_BAND_2': 0.012760999612510204,
#                               'RADIANCE_MULT_BAND_3': 0.011760000139474869,
#                               'RADIANCE_MULT_BAND_4': 0.009916399605572224,
#                               'RADIANCE_MULT_BAND_5': 0.006068299990147352,
#                               'RADIANCE_MULT_BAND_6': 0.0015090999659150839,
#                               'RADIANCE_MULT_BAND_7': 0.0005086599849164486,
#                               'RADIANCE_MULT_BAND_8': 0.011222999542951584,
#                               'RADIANCE_MULT_BAND_9': 0.0023715998977422714,
#                               'REFLECTANCE_ADD_BAND_1': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_2': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_3': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_4': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_5': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_6': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_7': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_8': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_9': -0.10000000149011612,
#                               'REFLECTANCE_MULT_BAND_1': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_2': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_3': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_4': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_5': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_6': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_7': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_8': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_9': 1.9999999494757503e-05,
#                               'REFLECTIVE_LINES': 7371,
#                               'REFLECTIVE_SAMPLES': 7571,
#                               'REQUEST_ID': '0501703096795_00022',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'RLUT_FILE_NAME': 'LC08RLUT_20130211_20150302_01_11.h5',
#                               'ROLL_ANGLE': -0.0010000000474974513,
#                               'SATURATION_BAND_1': 'Y',
#                               'SATURATION_BAND_2': 'Y',
#                               'SATURATION_BAND_3': 'Y',
#                               'SATURATION_BAND_4': 'Y',
#                               'SATURATION_BAND_5': 'Y',
#                               'SATURATION_BAND_6': 'Y',
#                               'SATURATION_BAND_7': 'Y',
#                               'SATURATION_BAND_8': 'N',
#                               'SATURATION_BAND_9': 'N',
#                               'SCENE_CENTER_TIME': '18:47:53.5627350Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 141.17710876464844,
#                               'SUN_ELEVATION': 57.44774627685547,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7371,
#                               'THERMAL_SAMPLES': 7571,
#                               'TIRS_SSM_MODEL': 'ACTUAL',
#                               'TIRS_SSM_POSITION_STATUS': 'NOMINAL',
#                               'TIRS_STRAY_LIGHT_CORRECTION_SOURCE': 'TIRS',
#                               'TRUNCATION_OLI': 'UPPER',
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'google:registration_count': 18,
#                               'google:registration_offset_x': -115.07379913330078,
#                               'google:registration_offset_y': -364.3538513183594,
#                               'google:registration_ratio': 0.19354838132858276,
#                               'system:asset_size': 1098728597,
#                               'system:footprint': {'coordinates': [[-122.92017273685738,
#                                                                     38.46498209751757],
#                                                                    [-122.93346937900016,
#                                                                     38.46731390123125],
#                                                                    [-123.38954163302972,
#                                                                     36.865387372060454],
#                                                                    [-123.30640230009647,
#                                                                     36.850193964022964],
#                                                                    [-122.82606743247868,
#                                                                     36.76121591681191],
#                                                                    [-121.3789749368328,
#                                                                     36.48015135796237],
#                                                                    [-121.31383149005752,
#                                                                     36.467055362266656],
#                                                                    [-121.31324154629195,
#                                                                     36.467968111167856],
#                                                                    [-121.23897311946787,
#                                                                     36.70866117712069],
#                                                                    [-121.07735759586336,
#                                                                     37.22734037239403],
#                                                                    [-121.05836110679148,
#                                                                     37.28789263894405],
#                                                                    [-121.01647196744659,
#                                                                     37.42143642241207],
#                                                                    [-120.95861723091869,
#                                                                     37.605271649747635],
#                                                                    [-120.911593520411,
#                                                                     37.75417459819205],
#                                                                    [-120.87621749401046,
#                                                                     37.86587231489448],
#                                                                    [-120.84241730319394,
#                                                                     37.97231352472051],
#                                                                    [-120.82509429033921,
#                                                                     38.02688887820374],
#                                                                    [-120.8129949822635,
#                                                                     38.06588993942728],
#                                                                    [-120.81293012362966,
#                                                                     38.06806725894663],
#                                                                    [-122.64735279887533,
#                                                                     38.41595954314546],
#                                                                    [-122.92017273685738,
#                                                                     38.46498209751757]],
#                                                    'type': 'LinearRing'},
#                               'system:index': 'LC08_044034_20130416',
#                               'system:time_start': 1366138073560},
#                'type': 'Image',
#                'version': 1576588724830660.0},
#               {'bands': [{'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B1'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B2'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B3'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B4'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B5'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B6'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B7'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [15, 0, 462592.5, 0, -15, 4257907.5],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [15141, 14741],
#                           'id': 'B8'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B9'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B10'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4257915],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'B11'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4257915],
#                           'data_type': {'max': 65535,
#                                         'min': 0,
#                                         'precision': 'int',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7371],
#                           'id': 'BQA'},
#                          {'crs': 'EPSG:4326',
#                           'crs_transform': [1, 0, 0, 0, 1, 0],
#                           'data_type': {'precision': 'double',
#                                         'type': 'PixelType'},
#                           'id': 'system:time_start'}],
#                'id': 'LANDSAT/LC08/C01/T1_TOA/LC08_044034_20130603',
#                'properties': {'BPF_NAME_OLI': 'LO8BPF20130603183403_20130603184925.01',
#                               'BPF_NAME_TIRS': 'LT8BPF20130603183010_20130603185017.01',
#                               'CLOUD_COVER': 37.75,
#                               'CLOUD_COVER_LAND': 9.350000381469727,
#                               'COLLECTION_CATEGORY': 'T1',
#                               'COLLECTION_NUMBER': 1,
#                               'CPF_NAME': 'LC08CPF_20130401_20130627_01.01',
#                               'DATA_TYPE': 'L1TP',
#                               'DATE_ACQUIRED': '2013-06-03',
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0144306421279907,
#                               'ELEVATION_SOURCE': 'GLS2000',
#                               'ELLIPSOID': 'WGS84',
#                               'FILE_DATE': 1489113471000,
#                               'GEOMETRIC_RMSE_MODEL': 5.669000148773193,
#                               'GEOMETRIC_RMSE_MODEL_X': 4.252999782562256,
#                               'GEOMETRIC_RMSE_MODEL_Y': 3.747999906539917,
#                               'GEOMETRIC_RMSE_VERIFY': 2.9730000495910645,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 443,
#                               'GROUND_CONTROL_POINTS_VERIFY': 166,
#                               'GROUND_CONTROL_POINTS_VERSION': 4,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8853149414062,
#                               'K1_CONSTANT_BAND_11': 480.8883056640625,
#                               'K2_CONSTANT_BAND_10': 1321.078857421875,
#                               'K2_CONSTANT_BAND_11': 1201.1441650390625,
#                               'LANDSAT_PRODUCT_ID': 'LC08_L1TP_044034_20130603_20170310_01_T1',
#                               'LANDSAT_SCENE_ID': 'LC80440342013154LGN01',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'PANCHROMATIC_LINES': 14741,
#                               'PANCHROMATIC_SAMPLES': 15141,
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_2.7.0',
#                               'RADIANCE_ADD_BAND_1': -61.00537109375,
#                               'RADIANCE_ADD_BAND_10': 0.10000000149011612,
#                               'RADIANCE_ADD_BAND_11': 0.10000000149011612,
#                               'RADIANCE_ADD_BAND_2': -62.47024154663086,
#                               'RADIANCE_ADD_BAND_3': -57.56578826904297,
#                               'RADIANCE_ADD_BAND_4': -48.542720794677734,
#                               'RADIANCE_ADD_BAND_5': -29.705720901489258,
#                               'RADIANCE_ADD_BAND_6': -7.387539863586426,
#                               'RADIANCE_ADD_BAND_7': -2.490000009536743,
#                               'RADIANCE_ADD_BAND_8': -54.9370002746582,
#                               'RADIANCE_ADD_BAND_9': -11.60966968536377,
#                               'RADIANCE_MULT_BAND_1': 0.01220100000500679,
#                               'RADIANCE_MULT_BAND_10': 0.00033420001273043454,
#                               'RADIANCE_MULT_BAND_11': 0.00033420001273043454,
#                               'RADIANCE_MULT_BAND_2': 0.012493999674916267,
#                               'RADIANCE_MULT_BAND_3': 0.0115130003541708,
#                               'RADIANCE_MULT_BAND_4': 0.009708499535918236,
#                               'RADIANCE_MULT_BAND_5': 0.00594109995290637,
#                               'RADIANCE_MULT_BAND_6': 0.001477499958127737,
#                               'RADIANCE_MULT_BAND_7': 0.0004980000085197389,
#                               'RADIANCE_MULT_BAND_8': 0.010986999608576298,
#                               'RADIANCE_MULT_BAND_9': 0.00232190010137856,
#                               'REFLECTANCE_ADD_BAND_1': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_2': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_3': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_4': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_5': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_6': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_7': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_8': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_9': -0.10000000149011612,
#                               'REFLECTANCE_MULT_BAND_1': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_2': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_3': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_4': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_5': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_6': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_7': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_8': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_9': 1.9999999494757503e-05,
#                               'REFLECTIVE_LINES': 7371,
#                               'REFLECTIVE_SAMPLES': 7571,
#                               'REQUEST_ID': '0501703096358_00034',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'RLUT_FILE_NAME': 'LC08RLUT_20130211_20150302_01_11.h5',
#                               'ROLL_ANGLE': -0.0010000000474974513,
#                               'SATURATION_BAND_1': 'Y',
#                               'SATURATION_BAND_2': 'Y',
#                               'SATURATION_BAND_3': 'Y',
#                               'SATURATION_BAND_4': 'Y',
#                               'SATURATION_BAND_5': 'Y',
#                               'SATURATION_BAND_6': 'Y',
#                               'SATURATION_BAND_7': 'Y',
#                               'SATURATION_BAND_8': 'N',
#                               'SATURATION_BAND_9': 'N',
#                               'SCENE_CENTER_TIME': '18:48:07.5781770Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 126.16896057128906,
#                               'SUN_ELEVATION': 67.34151458740234,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7371,
#                               'THERMAL_SAMPLES': 7571,
#                               'TIRS_SSM_MODEL': 'ACTUAL',
#                               'TIRS_SSM_POSITION_STATUS': 'NOMINAL',
#                               'TIRS_STRAY_LIGHT_CORRECTION_SOURCE': 'TIRS',
#                               'TRUNCATION_OLI': 'UPPER',
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'google:registration_count': 18,
#                               'google:registration_offset_x': -390.069580078125,
#                               'google:registration_offset_y': -206.31591796875,
#                               'google:registration_ratio': 0.19148936867713928,
#                               'system:asset_size': 1174502956,
#                               'system:footprint': {'coordinates': [[-121.3406141084292,
#                                                                     36.46693080957713],
#                                                                    [-121.34000510189266,
#                                                                     36.46876356452857],
#                                                                    [-121.21626627101907,
#                                                                     36.86975488201229],
#                                                                    [-121.08553626968369,
#                                                                     37.28841858523316],
#                                                                    [-121.03858064252616,
#                                                                     37.438002706631885],
#                                                                    [-121.01192332068602,
#                                                                     37.52272324339437],
#                                                                    [-120.94979295628131,
#                                                                     37.71969050917394],
#                                                                    [-120.8799681945822,
#                                                                     37.94008187146466],
#                                                                    [-120.85450636380008,
#                                                                     38.02038516187185],
#                                                                    [-120.84433384140574,
#                                                                     38.0526399961096],
#                                                                    [-120.83961595975282,
#                                                                     38.06775878705627],
#                                                                    [-122.46944808881622,
#                                                                     38.37838431500505],
#                                                                    [-122.95895723970908,
#                                                                     38.46677445707949],
#                                                                    [-122.96120381393823,
#                                                                     38.46677527444716],
#                                                                    [-122.96317424188037,
#                                                                     38.460589295829486],
# ...
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Number of product lines for the '
#                                'reflective bands.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>REFLECTIVE_SAMPLES</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Number of product samples for the '
#                                'reflective bands.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>REQUEST_ID</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Request id, nnnyymmdd0000_0000</p>\n'
#                                '<ul>\n'
#                                '<li>nnn = node number</li>\n'
#                                '<li>yy = year</li>\n'
#                                '<li>mm = month</li>\n'
#                                '<li>dd = day</li>\n'
#                                '</ul></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>RESAMPLING_OPTION</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Resampling option used in creating the '
#                                'image.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>RLUT_FILE_NAME</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>The file name for the Response '
#                                'Linearization Lookup Table (RLUT) used to '
#                                'generate the product, if applicable.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>ROLL_ANGLE</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>The amount of spacecraft roll angle at '
#                                'the scene center.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_1</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 1 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_10</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 10 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_11</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 11 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_2</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 2 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_3</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 3 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_4</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 4 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_5</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 5 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_6</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 6 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_7</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 7 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_8</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 8 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_9</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 9 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SCENE_CENTER_TIME</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Scene center time of acquired image. '
#                                'HH:MM:SS.SSSSSSSZ</p>\n'
#                                '<ul>\n'
#                                '<li>HH = Hour (00-23)</li>\n'
#                                '<li>MM = Minutes</li>\n'
#                                '<li>SS.SSSSSSS = Fractional seconds</li>\n'
#                                '<li>Z = &quot;Zulu&quot; time (same as '
#                                'GMT)</li>\n'
#                                '</ul></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SENSOR_ID</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Sensor used to capture data.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SPACECRAFT_ID</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Spacecraft identification.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>STATION_ID</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Ground Station/Organisation that '
#                                'received the data.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SUN_AZIMUTH</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Sun azimuth angle in degrees for the '
#                                'image center location at the image centre '
#                                'acquisition time.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SUN_ELEVATION</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Sun elevation angle in degrees for the '
#                                'image center location at the image centre '
#                                'acquisition time.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>TARGET_WRS_PATH</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Nearest WRS-2 path to the line-of-sight '
#                                'scene center of the image.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>TARGET_WRS_ROW</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Nearest WRS-2 row to the line-of-sight '
#                                'scene center of the image. Rows 880-889 and '
#                                '990-999 are reserved for the polar regions '
#                                'where it is undefined in the WRS-2.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>THERMAL_LINES</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Number of product lines for the thermal '
#                                'band.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>THERMAL_SAMPLES</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Number of product samples for the '
#                                'thermal band.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>TIRS_SSM_MODEL</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Due to an anomalous condition on the '
#                                'Thermal Infrared\n'
#                                'Sensor (TIRS) Scene Select Mirror (SSM) '
#                                'encoder electronics,\n'
#                                'this field has been added to indicate which '
#                                'model was used to process the data.\n'
#                                '(Actual, Preliminary, Final)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>TIRS_SSM_POSITION_STATUS</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>TIRS SSM position status.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>TIRS_STRAY_LIGHT_CORRECTION_SOURCE</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>TIRS stray light correction '
#                                'source.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>TRUNCATION_OLI</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Region of OLCI truncated.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>UTM_ZONE</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>UTM zone number used in product map '
#                                'projection.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>WRS_PATH</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>The WRS orbital path number (001 - '
#                                '251).</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>WRS_ROW</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Landsat satellite WRS row '
#                                '(001-248).</p></td>\n'
#                                '</tr>\n'
#                                '</table>\n'
#                                '<style>\n'
#                                '  table.eecat {\n'
#                                '  border: 1px solid black;\n'
#                                '  border-collapse: collapse;\n'
#                                '  font-size: 13px;\n'
#                                '  }\n'
#                                '  table.eecat td, tr, th {\n'
#                                '  text-align: left; vertical-align: top;\n'
#                                '  border: 1px solid gray; padding: 3px;\n'
#                                '  }\n'
#                                '  td.nobreak { white-space: nowrap; }\n'
#                                '</style>',
#                 'period': 0,
#                 'product_tags': ['global',
#                                  'toa',
#                                  'oli_tirs',
#                                  'tier1',
#                                  'c1',
#                                  't1',
#                                  'radiance',
#                                  'l8',
#                                  'lc8'],
#                 'provider': 'USGS/Google',
#                 'provider_url': 'http://landsat.usgs.gov/',
#                 'sample': 'https://mw1.google.com/ges/dd/images/LANDSAT_TOA_sample.png',
#                 'source_tags': ['landsat', 'usgs'],
#                 'system:visualization_0_bands': 'B4,B3,B2',
#                 'system:visualization_0_max': '30000.0',
#                 'system:visualization_0_min': '0.0',
#                 'system:visualization_0_name': 'True Color (432)',
#                 'system:visualization_1_bands': 'B5,B4,B3',
#                 'system:visualization_1_max': '30000.0',
#                 'system:visualization_1_min': '0.0',
#                 'system:visualization_1_name': 'Near Infrared (543)',
#                 'system:visualization_2_bands': 'B7,B5,B3',
#                 'system:visualization_2_max': '30000.0',
#                 'system:visualization_2_min': '0.0',
#                 'system:visualization_2_name': 'Shortwave Infrared (753)',
#                 'tags': ['landsat',
#                          'usgs',
#                          'global',
#                          'toa',
#                          'oli_tirs',
#                          'tier1',
#                          'c1',
#                          't1',
#                          'radiance',
#                          'l8',
#                          'lc8'],
#                 'thumb': 'https://mw1.google.com/ges/dd/images/LANDSAT_TOA_thumb.png',
#                 'title': 'USGS Landsat 8 Collection 1 Tier 1 TOA Reflectance',
#                 'type_name': 'ImageCollection',
#                 'visualization_0_bands': 'B4,B3,B2',
#                 'visualization_0_gain': '500.0',
#                 'visualization_0_max': '30000.0',
#                 'visualization_0_min': '0.0',
#                 'visualization_0_name': 'True Color (432)',
#                 'visualization_1_bands': 'B5,B4,B3',
#                 'visualization_1_gain': '500.0',
#                 'visualization_1_max': '30000.0',
#                 'visualization_1_min': '0.0',
#                 'visualization_1_name': 'Near Infrared (543)',
#                 'visualization_2_bands': 'B7,B5,B3',
#                 'visualization_2_gain': '500.0',
#                 'visualization_2_max': '30000.0',
#                 'visualization_2_min': '0.0',
#                 'visualization_2_name': 'Shortwave Infrared (753)'},
#  'type': 'ImageCollection',
#  'version': 1576588724830660.0}

# %% [markdown]
# Note that in the predefined function, the **metadata()** method is used to create a new Image from the value of a property. As discussed in the *Reducing* and *Compositing* sections, having that time band is useful for the linear modeling of change and for making composites.
#
# The mapped function is limited in the operations it can perform. Specifically, it can’t modify variables outside the function; it can’t print anything; it can’t use JavaScript ‘if’ or ‘for’ statements. However, you can use **ee.Algorithms.If()** to perform conditional operations in a mapped function.

# %%
# Load a Landsat 8 collection for a single path-row.
collection = ee.ImageCollection('LANDSAT/LC8_L1T_TOA').filter(ee.Filter.eq('WRS_PATH', 44)).filter(ee.Filter.eq('WRS_ROW', 34))

# This function uses a conditional statement to return the image if
# the solar elevation > 40 degrees.  Otherwise it returns a zero image.
def conditional(image):
	return ee.Algorithms.If(ee.Number(image.get('SUN_ELEVATION')).gt(40), image, ee.Image(0))

# Map the function over the collection, convert to a List and print the result.
print('Expand this to see the result: ')
pprint(collection.map(conditional).limit(3).getInfo())
# Out:
# Expand this to see the result:
# {'bands': [],
#  'features': [{'bands': [{'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B1'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B2'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B3'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B4'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B5'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B6'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B7'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [15, 0, 464992.5, 0, -15, 4258207.5],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [15141, 14761],
#                           'id': 'B8'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B9'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B10'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B11'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 464985, 0, -30, 4258215],
#                           'data_type': {'max': 65535,
#                                         'min': 0,
#                                         'precision': 'int',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'BQA'}],
#                'id': 'LANDSAT/LC8_L1T_TOA/LC80440342013106LGN01',
#                'properties': {'BPF_NAME_OLI': 'LO8BPF20130416183813_20130416184936.01',
#                               'BPF_NAME_TIRS': 'LT8BPF20130416183419_20130416185028.01',
#                               'CLOUD_COVER': 0.3499999940395355,
#                               'CORNER_LL_LAT_PRODUCT': 36.47584915161133,
#                               'CORNER_LL_LON_PRODUCT': -123.39070129394531,
#                               'CORNER_LL_PROJECTION_X_PRODUCT': 465000,
#                               'CORNER_LL_PROJECTION_Y_PRODUCT': 4036800,
#                               'CORNER_LR_LAT_PRODUCT': 36.45722961425781,
#                               'CORNER_LR_LON_PRODUCT': -120.85627746582031,
#                               'CORNER_LR_PROJECTION_X_PRODUCT': 692100,
#                               'CORNER_LR_PROJECTION_Y_PRODUCT': 4036800,
#                               'CORNER_UL_LAT_PRODUCT': 38.471431732177734,
#                               'CORNER_UL_LON_PRODUCT': -123.40122985839844,
#                               'CORNER_UL_PROJECTION_X_PRODUCT': 465000,
#                               'CORNER_UL_PROJECTION_Y_PRODUCT': 4258200,
#                               'CORNER_UR_LAT_PRODUCT': 38.45143127441406,
#                               'CORNER_UR_LON_PRODUCT': -120.79856872558594,
#                               'CORNER_UR_PROJECTION_X_PRODUCT': 692100,
#                               'CORNER_UR_PROJECTION_Y_PRODUCT': 4258200,
#                               'CPF_NAME': 'L8CPF20130401_20130627.08',
#                               'DATA_TYPE': 'L1T',
#                               'DATE_ACQUIRED': '2013-04-16',
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0037447214126587,
#                               'ELEVATION_SOURCE': 'GLS2000',
#                               'ELLIPSOID': 'WGS84',
#                               'FILE_DATE': 1421185515000,
#                               'GEOMETRIC_RMSE_MODEL': 6.077000141143799,
#                               'GEOMETRIC_RMSE_MODEL_X': 4.224999904632568,
#                               'GEOMETRIC_RMSE_MODEL_Y': 4.368000030517578,
#                               'GEOMETRIC_RMSE_VERIFY': 3.6070001125335693,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 475,
#                               'GROUND_CONTROL_POINTS_VERIFY': 168,
#                               'GROUND_CONTROL_POINTS_VERSION': 2,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8900146484375,
#                               'K1_CONSTANT_BAND_11': 480.8900146484375,
#                               'K2_CONSTANT_BAND_10': 1321.0799560546875,
#                               'K2_CONSTANT_BAND_11': 1201.1400146484375,
#                               'LANDSAT_SCENE_ID': 'LC80440342013106LGN01',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'ORIGIN': 'Image courtesy of the U.S. Geological '
#                                         'Survey',
#                               'PANCHROMATIC_LINES': 14761,
#                               'PANCHROMATIC_SAMPLES': 15141,
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_2.4.0',
#                               'QUANTIZE_CAL_MAX_BAND_1': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_10': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_11': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_2': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_3': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_4': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_5': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_6': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_7': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_8': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_9': 65535,
#                               'QUANTIZE_CAL_MIN_BAND_1': 1,
#                               'QUANTIZE_CAL_MIN_BAND_10': 1,
#                               'QUANTIZE_CAL_MIN_BAND_11': 1,
#                               'QUANTIZE_CAL_MIN_BAND_2': 1,
#                               'QUANTIZE_CAL_MIN_BAND_3': 1,
#                               'QUANTIZE_CAL_MIN_BAND_4': 1,
#                               'QUANTIZE_CAL_MIN_BAND_5': 1,
#                               'QUANTIZE_CAL_MIN_BAND_6': 1,
#                               'QUANTIZE_CAL_MIN_BAND_7': 1,
#                               'QUANTIZE_CAL_MIN_BAND_8': 1,
#                               'QUANTIZE_CAL_MIN_BAND_9': 1,
#                               'RADIANCE_ADD_BAND_1': -62.31122970581055,
#                               'RADIANCE_ADD_BAND_10': 0.10000000149011612,
#                               'RADIANCE_ADD_BAND_11': 0.10000000149011612,
#                               'RADIANCE_ADD_BAND_2': -63.80746078491211,
#                               'RADIANCE_ADD_BAND_3': -58.798030853271484,
#                               'RADIANCE_ADD_BAND_4': -49.581809997558594,
#                               'RADIANCE_ADD_BAND_5': -30.34160041809082,
#                               'RADIANCE_ADD_BAND_6': -7.545680046081543,
#                               'RADIANCE_ADD_BAND_7': -2.543299913406372,
#                               'RADIANCE_ADD_BAND_8': -56.11296081542969,
#                               'RADIANCE_ADD_BAND_9': -11.858180046081543,
#                               'RADIANCE_MAXIMUM_BAND_1': 754.402099609375,
#                               'RADIANCE_MAXIMUM_BAND_10': 22.001800537109375,
#                               'RADIANCE_MAXIMUM_BAND_11': 22.001800537109375,
#                               'RADIANCE_MAXIMUM_BAND_2': 772.5169067382812,
#                               'RADIANCE_MAXIMUM_BAND_3': 711.8677368164062,
#                               'RADIANCE_MAXIMUM_BAND_4': 600.2869873046875,
#                               'RADIANCE_MAXIMUM_BAND_5': 367.345703125,
#                               'RADIANCE_MAXIMUM_BAND_6': 91.35553741455078,
#                               'RADIANCE_MAXIMUM_BAND_7': 30.791709899902344,
#                               'RADIANCE_MAXIMUM_BAND_8': 679.3596801757812,
#                               'RADIANCE_MAXIMUM_BAND_9': 143.56703186035156,
#                               'RADIANCE_MINIMUM_BAND_1': -62.298770904541016,
#                               'RADIANCE_MINIMUM_BAND_10': 0.10033000260591507,
#                               'RADIANCE_MINIMUM_BAND_11': 0.10033000260591507,
#                               'RADIANCE_MINIMUM_BAND_2': -63.794700622558594,
#                               'RADIANCE_MINIMUM_BAND_3': -58.78627014160156,
#                               'RADIANCE_MINIMUM_BAND_4': -49.5718994140625,
#                               'RADIANCE_MINIMUM_BAND_5': -30.335529327392578,
#                               'RADIANCE_MINIMUM_BAND_6': -7.544169902801514,
#                               'RADIANCE_MINIMUM_BAND_7': -2.542789936065674,
#                               'RADIANCE_MINIMUM_BAND_8': -56.101741790771484,
#                               'RADIANCE_MINIMUM_BAND_9': -11.855810165405273,
#                               'RADIANCE_MULT_BAND_1': 0.012462000362575054,
#                               'RADIANCE_MULT_BAND_10': 0.00033420001273043454,
#                               'RADIANCE_MULT_BAND_11': 0.00033420001273043454,
#                               'RADIANCE_MULT_BAND_2': 0.012760999612510204,
#                               'RADIANCE_MULT_BAND_3': 0.011760000139474869,
#                               'RADIANCE_MULT_BAND_4': 0.009916399605572224,
#                               'RADIANCE_MULT_BAND_5': 0.006068299990147352,
#                               'RADIANCE_MULT_BAND_6': 0.0015090999659150839,
#                               'RADIANCE_MULT_BAND_7': 0.0005086599849164486,
#                               'RADIANCE_MULT_BAND_8': 0.011222999542951584,
#                               'RADIANCE_MULT_BAND_9': 0.0023715998977422714,
#                               'REFLECTANCE_ADD_BAND_1': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_2': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_3': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_4': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_5': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_6': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_7': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_8': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_9': -0.10000000149011612,
#                               'REFLECTANCE_MAXIMUM_BAND_1': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_2': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_3': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_4': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_5': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_6': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_7': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_8': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_9': 1.2107000350952148,
#                               'REFLECTANCE_MINIMUM_BAND_1': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_2': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_3': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_4': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_5': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_6': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_7': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_8': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_9': -0.09997999668121338,
#                               'REFLECTANCE_MULT_BAND_1': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_2': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_3': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_4': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_5': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_6': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_7': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_8': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_9': 1.9999999494757503e-05,
#                               'REFLECTIVE_LINES': 7381,
#                               'REFLECTIVE_SAMPLES': 7571,
#                               'REQUEST_ID': '0601501132587_00002',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'RLUT_FILE_NAME': 'L8RLUT20130211_20431231v09.h5',
#                               'ROLL_ANGLE': -0.0010000000474974513,
#                               'SCENE_CENTER_TIME': '18:47:53.5577434Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 140.98756408691406,
#                               'SUN_ELEVATION': 57.591468811035156,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7381,
#                               'THERMAL_SAMPLES': 7571,
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'catalog_cloud_cover': 0,
#                               'catalog_image_quality1': 9,
#                               'google:cloud_storage_path': 'gs://earthengine-public/landsat/L8/044/034/LC80440342013106LGN01.tar.bz',
#                               'google:registration_count': 21,
#                               'google:registration_offset_x': 292.5033874511719,
#                               'google:registration_offset_y': -301.9111022949219,
#                               'google:registration_ratio': 0.25925925374031067,
#                               'system:asset_size': 1105641883,
#                               'system:footprint': {'coordinates': [[-122.9311059298748,
#                                                                     38.468856913670805],
#                                                                    [-123.38828669780919,
#                                                                     36.86340523669095],
#                                                                    [-121.31538126751141,
#                                                                     36.46540746956072],
#                                                                    [-120.81312145650155,
#                                                                     38.07027267083632],
#                                                                    [-122.9311059298748,
#                                                                     38.468856913670805]],
#                                                    'type': 'LinearRing'},
#                               'system:index': 'LC80440342013106LGN01',
#                               'system:time_end': 1366138073557,
#                               'system:time_start': 1366138073557},
#                'type': 'Image',
#                'version': 1576588736739853},
#               {'bands': [{'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B1'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B2'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B3'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B4'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B5'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B6'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B7'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [15, 0, 462592.5, 0, -15, 4258207.5],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [15141, 14761],
#                           'id': 'B8'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B9'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B10'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B11'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 462585, 0, -30, 4258215],
#                           'data_type': {'max': 65535,
#                                         'min': 0,
#                                         'precision': 'int',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'BQA'}],
#                'id': 'LANDSAT/LC8_L1T_TOA/LC80440342013154LGN00',
#                'properties': {'BPF_NAME_OLI': 'LO8BPF20130603183403_20130603184925.01',
#                               'BPF_NAME_TIRS': 'LT8BPF20130603183010_20130603185017.01',
#                               'CLOUD_COVER': 35.400001525878906,
#                               'CORNER_LL_LAT_PRODUCT': 36.47576141357422,
#                               'CORNER_LL_LON_PRODUCT': -123.41748809814453,
#                               'CORNER_LL_PROJECTION_X_PRODUCT': 462600,
#                               'CORNER_LL_PROJECTION_Y_PRODUCT': 4036800,
#                               'CORNER_LR_LAT_PRODUCT': 36.45771026611328,
#                               'CORNER_LR_LON_PRODUCT': -120.88304901123047,
#                               'CORNER_LR_PROJECTION_X_PRODUCT': 689700,
#                               'CORNER_LR_PROJECTION_Y_PRODUCT': 4036800,
#                               'CORNER_UL_LAT_PRODUCT': 38.47134017944336,
#                               'CORNER_UL_LON_PRODUCT': -123.42874145507812,
#                               'CORNER_UL_PROJECTION_X_PRODUCT': 462600,
#                               'CORNER_UL_PROJECTION_Y_PRODUCT': 4258200,
#                               'CORNER_UR_LAT_PRODUCT': 38.45195007324219,
#                               'CORNER_UR_LON_PRODUCT': -120.8260498046875,
#                               'CORNER_UR_PROJECTION_X_PRODUCT': 689700,
#                               'CORNER_UR_PROJECTION_Y_PRODUCT': 4258200,
#                               'CPF_NAME': 'L8CPF20130401_20130627.08',
#                               'DATA_TYPE': 'L1T',
#                               'DATE_ACQUIRED': '2013-06-03',
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0144306421279907,
#                               'ELEVATION_SOURCE': 'GLS2000',
#                               'ELLIPSOID': 'WGS84',
#                               'FILE_DATE': 1421183995000,
#                               'GEOMETRIC_RMSE_MODEL': 5.669000148773193,
#                               'GEOMETRIC_RMSE_MODEL_X': 4.254000186920166,
#                               'GEOMETRIC_RMSE_MODEL_Y': 3.747999906539917,
#                               'GEOMETRIC_RMSE_VERIFY': 2.9739999771118164,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 443,
#                               'GROUND_CONTROL_POINTS_VERIFY': 166,
#                               'GROUND_CONTROL_POINTS_VERSION': 2,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8900146484375,
#                               'K1_CONSTANT_BAND_11': 480.8900146484375,
#                               'K2_CONSTANT_BAND_10': 1321.0799560546875,
#                               'K2_CONSTANT_BAND_11': 1201.1400146484375,
#                               'LANDSAT_SCENE_ID': 'LC80440342013154LGN00',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'ORIGIN': 'Image courtesy of the U.S. Geological '
#                                         'Survey',
#                               'PANCHROMATIC_LINES': 14761,
#                               'PANCHROMATIC_SAMPLES': 15141,
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_2.4.0',
#                               'QUANTIZE_CAL_MAX_BAND_1': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_10': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_11': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_2': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_3': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_4': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_5': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_6': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_7': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_8': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_9': 65535,
#                               'QUANTIZE_CAL_MIN_BAND_1': 1,
#                               'QUANTIZE_CAL_MIN_BAND_10': 1,
#                               'QUANTIZE_CAL_MIN_BAND_11': 1,
#                               'QUANTIZE_CAL_MIN_BAND_2': 1,
#                               'QUANTIZE_CAL_MIN_BAND_3': 1,
#                               'QUANTIZE_CAL_MIN_BAND_4': 1,
#                               'QUANTIZE_CAL_MIN_BAND_5': 1,
#                               'QUANTIZE_CAL_MIN_BAND_6': 1,
#                               'QUANTIZE_CAL_MIN_BAND_7': 1,
#                               'QUANTIZE_CAL_MIN_BAND_8': 1,
#                               'QUANTIZE_CAL_MIN_BAND_9': 1,
#                               'RADIANCE_ADD_BAND_1': -61.00537109375,
#                               'RADIANCE_ADD_BAND_10': 0.10000000149011612,
#                               'RADIANCE_ADD_BAND_11': 0.10000000149011612,
#                               'RADIANCE_ADD_BAND_2': -62.47024154663086,
#                               'RADIANCE_ADD_BAND_3': -57.56578826904297,
#                               'RADIANCE_ADD_BAND_4': -48.542720794677734,
#                               'RADIANCE_ADD_BAND_5': -29.705720901489258,
#                               'RADIANCE_ADD_BAND_6': -7.387539863586426,
#                               'RADIANCE_ADD_BAND_7': -2.490000009536743,
#                               'RADIANCE_ADD_BAND_8': -54.9370002746582,
#                               'RADIANCE_ADD_BAND_9': -11.60966968536377,
#                               'RADIANCE_MAXIMUM_BAND_1': 738.5919799804688,
#                               'RADIANCE_MAXIMUM_BAND_10': 22.001800537109375,
#                               'RADIANCE_MAXIMUM_BAND_11': 22.001800537109375,
#                               'RADIANCE_MAXIMUM_BAND_2': 756.3272094726562,
#                               'RADIANCE_MAXIMUM_BAND_3': 696.9490356445312,
#                               'RADIANCE_MAXIMUM_BAND_4': 587.7066650390625,
#                               'RADIANCE_MAXIMUM_BAND_5': 359.6471862792969,
#                               'RADIANCE_MAXIMUM_BAND_6': 89.44098663330078,
#                               'RADIANCE_MAXIMUM_BAND_7': 30.146400451660156,
#                               'RADIANCE_MAXIMUM_BAND_8': 665.1222534179688,
#                               'RADIANCE_MAXIMUM_BAND_9': 140.5582733154297,
#                               'RADIANCE_MINIMUM_BAND_1': -60.993160247802734,
#                               'RADIANCE_MINIMUM_BAND_10': 0.10033000260591507,
#                               'RADIANCE_MINIMUM_BAND_11': 0.10033000260591507,
#                               'RADIANCE_MINIMUM_BAND_2': -62.457740783691406,
#                               'RADIANCE_MINIMUM_BAND_3': -57.55427932739258,
#                               'RADIANCE_MINIMUM_BAND_4': -48.53300857543945,
#                               'RADIANCE_MINIMUM_BAND_5': -29.699779510498047,
#                               'RADIANCE_MINIMUM_BAND_6': -7.3860697746276855,
#                               'RADIANCE_MINIMUM_BAND_7': -2.489500045776367,
#                               'RADIANCE_MINIMUM_BAND_8': -54.92601013183594,
#                               'RADIANCE_MINIMUM_BAND_9': -11.60735034942627,
#                               'RADIANCE_MULT_BAND_1': 0.01220100000500679,
#                               'RADIANCE_MULT_BAND_10': 0.00033420001273043454,
#                               'RADIANCE_MULT_BAND_11': 0.00033420001273043454,
#                               'RADIANCE_MULT_BAND_2': 0.012493999674916267,
#                               'RADIANCE_MULT_BAND_3': 0.0115130003541708,
#                               'RADIANCE_MULT_BAND_4': 0.009708499535918236,
#                               'RADIANCE_MULT_BAND_5': 0.00594109995290637,
#                               'RADIANCE_MULT_BAND_6': 0.001477499958127737,
#                               'RADIANCE_MULT_BAND_7': 0.0004980000085197389,
#                               'RADIANCE_MULT_BAND_8': 0.010986999608576298,
#                               'RADIANCE_MULT_BAND_9': 0.00232190010137856,
#                               'REFLECTANCE_ADD_BAND_1': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_2': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_3': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_4': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_5': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_6': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_7': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_8': -0.10000000149011612,
#                               'REFLECTANCE_ADD_BAND_9': -0.10000000149011612,
#                               'REFLECTANCE_MAXIMUM_BAND_1': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_2': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_3': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_4': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_5': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_6': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_7': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_8': 1.2107000350952148,
#                               'REFLECTANCE_MAXIMUM_BAND_9': 1.2107000350952148,
#                               'REFLECTANCE_MINIMUM_BAND_1': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_2': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_3': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_4': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_5': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_6': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_7': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_8': -0.09997999668121338,
#                               'REFLECTANCE_MINIMUM_BAND_9': -0.09997999668121338,
#                               'REFLECTANCE_MULT_BAND_1': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_2': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_3': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_4': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_5': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_6': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_7': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_8': 1.9999999494757503e-05,
#                               'REFLECTANCE_MULT_BAND_9': 1.9999999494757503e-05,
#                               'REFLECTIVE_LINES': 7381,
#                               'REFLECTIVE_SAMPLES': 7571,
#                               'REQUEST_ID': '0601501132404_00001',
#                               'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#                               'RLUT_FILE_NAME': 'L8RLUT20130211_20431231v09.h5',
#                               'ROLL_ANGLE': -0.0010000000474974513,
#                               'SCENE_CENTER_TIME': '18:48:07.5703948Z',
#                               'SENSOR_ID': 'OLI_TIRS',
#                               'SPACECRAFT_ID': 'LANDSAT_8',
#                               'STATION_ID': 'LGN',
#                               'SUN_AZIMUTH': 125.80250549316406,
#                               'SUN_ELEVATION': 67.44905853271484,
#                               'TARGET_WRS_PATH': 44,
#                               'TARGET_WRS_ROW': 34,
#                               'THERMAL_LINES': 7381,
#                               'THERMAL_SAMPLES': 7571,
#                               'UTM_ZONE': 10,
#                               'WRS_PATH': 44,
#                               'WRS_ROW': 34,
#                               'catalog_cloud_cover': 3,
#                               'catalog_image_quality1': 9,
#                               'google:cloud_storage_path': 'gs://earthengine-public/landsat/L8/044/034/LC80440342013154LGN00.tar.bz',
#                               'google:registration_count': 21,
#                               'google:registration_offset_x': -4.977896690368652,
#                               'google:registration_offset_y': 553.2953491210938,
#                               'google:registration_ratio': 0.2530120611190796,
#                               'system:asset_size': 1180039379,
#                               'system:footprint': {'coordinates': [[-122.95896145181437,
#                                                                     38.46914037796555],
#                                                                    [-123.41588609883141,
#                                                                     36.863582326233896],
#                                                                    [-121.34249180768978,
#                                                                     36.4657872062346],
#                                                                    [-120.84047952936048,
#                                                                     38.07023810949083],
#                                                                    [-122.95896145181437,
#                                                                     38.46914037796555]],
#                                                    'type': 'LinearRing'},
#                               'system:index': 'LC80440342013154LGN00',
#                               'system:time_end': 1370285287570,
#                               'system:time_start': 1370285287570},
#                'type': 'Image',
#                'version': 1576588736739853},
#               {'bands': [{'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 465885, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B1'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 465885, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B2'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 465885, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B3'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 465885, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B4'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 465885, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B5'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 465885, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B6'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 465885, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B7'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [15, 0, 465892.5, 0, -15, 4258207.5],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [15141, 14761],
#                           'id': 'B8'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 465885, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B9'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 465885, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B10'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 465885, 0, -30, 4258215],
#                           'data_type': {'precision': 'float',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'B11'},
#                          {'crs': 'EPSG:32610',
#                           'crs_transform': [30, 0, 465885, 0, -30, 4258215],
#                           'data_type': {'max': 65535,
#                                         'min': 0,
#                                         'precision': 'int',
#                                         'type': 'PixelType'},
#                           'dimensions': [7571, 7381],
#                           'id': 'BQA'}],
#                'id': 'LANDSAT/LC8_L1T_TOA/LC80440342013170LGN00',
#                'properties': {'BPF_NAME_OLI': 'LO8BPF20130619183555_20130619185006.01',
#                               'BPF_NAME_TIRS': 'LT8BPF20130619183202_20130619185058.01',
#                               'CLOUD_COVER': 0.47999998927116394,
#                               'CORNER_LL_LAT_PRODUCT': 36.47587966918945,
#                               'CORNER_LL_LON_PRODUCT': -123.38065338134766,
#                               'CORNER_LL_PROJECTION_X_PRODUCT': 465900,
#                               'CORNER_LL_PROJECTION_Y_PRODUCT': 4036800,
#                               'CORNER_LR_LAT_PRODUCT': 36.45705032348633,
#                               'CORNER_LR_LON_PRODUCT': -120.84625244140625,
#                               'CORNER_LR_PROJECTION_X_PRODUCT': 693000,
#                               'CORNER_LR_PROJECTION_Y_PRODUCT': 4036800,
#                               'CORNER_UL_LAT_PRODUCT': 38.47146987915039,
#                               'CORNER_UL_LON_PRODUCT': -123.39090728759766,
#                               'CORNER_UL_PROJECTION_X_PRODUCT': 465900,
#                               'CORNER_UL_PROJECTION_Y_PRODUCT': 4258200,
#                               'CORNER_UR_LAT_PRODUCT': 38.45124053955078,
#                               'CORNER_UR_LON_PRODUCT': -120.78826141357422,
#                               'CORNER_UR_PROJECTION_X_PRODUCT': 693000,
#                               'CORNER_UR_PROJECTION_Y_PRODUCT': 4258200,
#                               'CPF_NAME': 'L8CPF20130401_20130627.08',
#                               'DATA_TYPE': 'L1T',
#                               'DATE_ACQUIRED': '2013-06-19',
#                               'DATUM': 'WGS84',
#                               'EARTH_SUN_DISTANCE': 1.0161153078079224,
#                               'ELEVATION_SOURCE': 'GLS2000',
#                               'ELLIPSOID': 'WGS84',
#                               'FILE_DATE': 1417120710000,
#                               'GEOMETRIC_RMSE_MODEL': 5.033999919891357,
#                               'GEOMETRIC_RMSE_MODEL_X': 3.7699999809265137,
#                               'GEOMETRIC_RMSE_MODEL_Y': 3.3359999656677246,
#                               'GEOMETRIC_RMSE_VERIFY': 2.450000047683716,
#                               'GRID_CELL_SIZE_PANCHROMATIC': 15,
#                               'GRID_CELL_SIZE_REFLECTIVE': 30,
#                               'GRID_CELL_SIZE_THERMAL': 30,
#                               'GROUND_CONTROL_POINTS_MODEL': 535,
#                               'GROUND_CONTROL_POINTS_VERIFY': 152,
#                               'GROUND_CONTROL_POINTS_VERSION': 2,
#                               'IMAGE_QUALITY_OLI': 9,
#                               'IMAGE_QUALITY_TIRS': 9,
#                               'K1_CONSTANT_BAND_10': 774.8900146484375,
#                               'K1_CONSTANT_BAND_11': 480.8900146484375,
#                               'K2_CONSTANT_BAND_10': 1321.0799560546875,
#                               'K2_CONSTANT_BAND_11': 1201.1400146484375,
#                               'LANDSAT_SCENE_ID': 'LC80440342013170LGN00',
#                               'MAP_PROJECTION': 'UTM',
#                               'NADIR_OFFNADIR': 'NADIR',
#                               'ORIENTATION': 'NORTH_UP',
#                               'ORIGIN': 'Image courtesy of the U.S. Geological '
#                                         'Survey',
#                               'PANCHROMATIC_LINES': 14761,
#                               'PANCHROMATIC_SAMPLES': 15141,
#                               'PROCESSING_SOFTWARE_VERSION': 'LPGS_2.4.0',
#                               'QUANTIZE_CAL_MAX_BAND_1': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_10': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_11': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_2': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_3': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_4': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_5': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_6': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_7': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_8': 65535,
#                               'QUANTIZE_CAL_MAX_BAND_9': 65535,
#                               'QUANTIZE_CAL_MIN_BAND_1': 1,
#                               'QUANTIZE_CAL_MIN_BAND_10': 1,
#                               'QUANTIZE_CAL_MIN_BAND_11': 1,
#                               'QUANTIZE_CAL_MIN_BAND_2': 1,
#                               'QUANTIZE_CAL_MIN_BAND_3': 1,
#                               'QUANTIZE_CAL_MIN_BAND_4': 1,
#                               'QUANTIZE_CAL_MIN_BAND_5': 1,
#                               'QUANTIZE_CAL_MIN_BAND_6': 1,
#                               'QUANTIZE_CAL_MIN_BAND_7': 1,
#                               'QUANTIZE_CAL_MIN_BAND_8': 1,
#                               'QUANTIZE_CAL_MIN_BAND_9': 1,
#                               'RADIANCE_ADD_BAND_1': -60.80324935913086,
#                               'RADIANCE_ADD_BAND_10': 0.10000000149011612,
#                               'RADIANCE_ADD_BAND_11': 0.10000000149011612,
#                               'RADIANCE_ADD_BAND_2': -62.26327133178711,
#                               'RADIANCE_ADD_BAND_3': -57.37508010864258,
#                               'RADIANCE_ADD_BAND_4': -48.381900787353516,
#                               'RADIANCE_ADD_BAND_5': -29.607309341430664,
#                               'RADIANCE_ADD_BAND_6': -7.363070011138916,
#                               'RADIANCE_ADD_BAND_7': -2.481750011444092,
#                               'RADIANCE_ADD_BAND_8': -54.75498962402344,
#                               'RADIANCE_ADD_BAND_9': -11.571209907531738,
#                               'RADIANCE_MAXIMUM_BAND_1': 736.14501953125,
#                               'RADIANCE_MAXIMUM_BAND_10': 22.001800537109375,
#                               'RADIANCE_MAXIMUM_BAND_11': 22.001800537109375,
#                               'RADIANCE_MAXIMUM_BAND_2': 753.8214721679688,
#                               'RADIANCE_MAXIMUM_BAND_3': 694.6400146484375,
#                               'RADIANCE_MAXIMUM_BAND_4': 585.7595825195312,
#                               'RADIANCE_MAXIMUM_BAND_5': 358.4556579589844,
#                               'RADIANCE_MAXIMUM_BAND_6': 89.14466857910156,
#                               'RADIANCE_MAXIMUM_BAND_7': 30.046520233154297,
#                               'RADIANCE_MAXIMUM_BAND_8': 662.9186401367188,
#                               'RADIANCE_MAXIMUM_BAND_9': 140.0926055908203,
#                               'RADIANCE_MINIMUM_BAND_1': -60.791099548339844,
#                               'RADIANCE_MINIMUM_BAND_10': 0.10033000260591507,
#                               'RADIANCE_MINIMUM_BAND_11': 0.10033000260591507,
#                               'RADIANCE_MINIMUM_BAND_2': -62.25082015991211,
# ...
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>REFLECTIVE_LINES</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Number of product lines for the '
#                                'reflective bands.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>REFLECTIVE_SAMPLES</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Number of product samples for the '
#                                'reflective bands.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>REQUEST_ID</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Request id, nnnyymmdd0000_0000</p>\n'
#                                '<ul>\n'
#                                '<li>nnn = node number</li>\n'
#                                '<li>yy = year</li>\n'
#                                '<li>mm = month</li>\n'
#                                '<li>dd = day</li>\n'
#                                '</ul></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>RESAMPLING_OPTION</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Resampling option used in creating the '
#                                'image.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>RLUT_FILE_NAME</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>The file name for the Response '
#                                'Linearization Lookup Table (RLUT) used to '
#                                'generate the product, if applicable.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>ROLL_ANGLE</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>The amount of spacecraft roll angle at '
#                                'the scene center.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_1</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 1 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_10</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 10 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_11</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 11 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_2</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 2 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_3</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 3 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_4</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 4 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_5</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 5 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_6</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 6 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_7</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 7 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_8</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 8 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SATURATION_BAND_9</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Flag indicating saturated pixels for '
#                                'band 9 (&#39;Y&#39;/&#39;N&#39;)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SCENE_CENTER_TIME</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Scene center time of acquired image. '
#                                'HH:MM:SS.SSSSSSSZ</p>\n'
#                                '<ul>\n'
#                                '<li>HH = Hour (00-23)</li>\n'
#                                '<li>MM = Minutes</li>\n'
#                                '<li>SS.SSSSSSS = Fractional seconds</li>\n'
#                                '<li>Z = &quot;Zulu&quot; time (same as '
#                                'GMT)</li>\n'
#                                '</ul></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SENSOR_ID</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Sensor used to capture data.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SPACECRAFT_ID</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Spacecraft identification.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>STATION_ID</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Ground Station/Organisation that '
#                                'received the data.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SUN_AZIMUTH</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Sun azimuth angle in degrees for the '
#                                'image center location at the image centre '
#                                'acquisition time.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>SUN_ELEVATION</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Sun elevation angle in degrees for the '
#                                'image center location at the image centre '
#                                'acquisition time.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>TARGET_WRS_PATH</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Nearest WRS-2 path to the line-of-sight '
#                                'scene center of the image.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>TARGET_WRS_ROW</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Nearest WRS-2 row to the line-of-sight '
#                                'scene center of the image. Rows 880-889 and '
#                                '990-999 are reserved for the polar regions '
#                                'where it is undefined in the WRS-2.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>THERMAL_LINES</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Number of product lines for the thermal '
#                                'band.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>THERMAL_SAMPLES</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Number of product samples for the '
#                                'thermal band.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>TIRS_SSM_MODEL</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Due to an anomalous condition on the '
#                                'Thermal Infrared\n'
#                                'Sensor (TIRS) Scene Select Mirror (SSM) '
#                                'encoder electronics,\n'
#                                'this field has been added to indicate which '
#                                'model was used to process the data.\n'
#                                '(Actual, Preliminary, Final)</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>TIRS_SSM_POSITION_STATUS</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>TIRS SSM position status.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>TIRS_STRAY_LIGHT_CORRECTION_SOURCE</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>TIRS stray light correction '
#                                'source.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>TRUNCATION_OLI</td>\n'
#                                '<td>STRING</td>\n'
#                                '<td><p>Region of OLCI truncated.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>UTM_ZONE</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>UTM zone number used in product map '
#                                'projection.</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>WRS_PATH</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>The WRS orbital path number (001 - '
#                                '251).</p></td>\n'
#                                '</tr>\n'
#                                '<tr>\n'
#                                '<td>WRS_ROW</td>\n'
#                                '<td>DOUBLE</td>\n'
#                                '<td><p>Landsat satellite WRS row '
#                                '(001-248).</p></td>\n'
#                                '</tr>\n'
#                                '</table>\n'
#                                '<style>\n'
#                                '  table.eecat {\n'
#                                '  border: 1px solid black;\n'
#                                '  border-collapse: collapse;\n'
#                                '  font-size: 13px;\n'
#                                '  }\n'
#                                '  table.eecat td, tr, th {\n'
#                                '  text-align: left; vertical-align: top;\n'
#                                '  border: 1px solid gray; padding: 3px;\n'
#                                '  }\n'
#                                '  td.nobreak { white-space: nowrap; }\n'
#                                '</style>',
#                 'period': 0,
#                 'product_tags': ['global',
#                                  'toa',
#                                  'oli_tirs',
#                                  'radiance',
#                                  'l8',
#                                  'lc8'],
#                 'provider': 'USGS/Google',
#                 'provider_url': 'http://landsat.usgs.gov/',
#                 'sample': 'https://mw1.google.com/ges/dd/images/LANDSAT_RAW_sample.png',
#                 'source_tags': ['landsat', 'usgs'],
#                 'superseded_by': 'LANDSAT/LC08/C01/T1_TOA',
#                 'system:visualization_0_bands': 'B4,B3,B2',
#                 'system:visualization_0_max': '30000.0',
#                 'system:visualization_0_min': '0.0',
#                 'system:visualization_0_name': 'True Color (432)',
#                 'system:visualization_1_bands': 'B5,B4,B3',
#                 'system:visualization_1_max': '30000.0',
#                 'system:visualization_1_min': '0.0',
#                 'system:visualization_1_name': 'Near Infrared (543)',
#                 'system:visualization_2_bands': 'B7,B5,B3',
#                 'system:visualization_2_max': '30000.0',
#                 'system:visualization_2_min': '0.0',
#                 'system:visualization_2_name': 'Shortwave Infrared (753)',
#                 'tags': ['landsat',
#                          'usgs',
#                          'global',
#                          'toa',
#                          'oli_tirs',
#                          'radiance',
#                          'l8',
#                          'lc8'],
#                 'thumb': 'https://mw1.google.com/ges/dd/images/LANDSAT_RAW_thumb.png',
#                 'title': 'USGS Landsat 8 TOA Reflectance (Orthorectified)',
#                 'type_name': 'ImageCollection',
#                 'visualization_0_bands': 'B4,B3,B2',
#                 'visualization_0_gain': '500.0',
#                 'visualization_0_max': '30000.0',
#                 'visualization_0_min': '0.0',
#                 'visualization_0_name': 'True Color (432)',
#                 'visualization_1_bands': 'B5,B4,B3',
#                 'visualization_1_gain': '500.0',
#                 'visualization_1_max': '30000.0',
#                 'visualization_1_min': '0.0',
#                 'visualization_1_name': 'Near Infrared (543)',
#                 'visualization_2_bands': 'B7,B5,B3',
#                 'visualization_2_gain': '500.0',
#                 'visualization_2_max': '30000.0',
#                 'visualization_2_min': '0.0',
#                 'visualization_2_name': 'Shortwave Infrared (753)'},
#  'type': 'ImageCollection',
#  'version': 1576588736739853}

# %% [markdown]
# Inspect the list of images in the output ImageCollection and note that the when the condition evaluated by the **If()** algorithm is true, the output contains a constant image. Although this demonstrates a server-side conditional function (learn more about client vs. server in Earth Engine on this page), avoid **If()** in general and use filters instead.

# %% [markdown]
# # 5. Reducing an ImageCollection
#
# To composite images in an **ImageCollection**, use **imageCollection.reduce()**. This will composite all the images in the collection to a single image representing, for example, the min, max, mean or standard deviation of the images. (See the Reducers section for more information about reducers). For example, to create a median value image from a collection:

# %%
# Load a Landsat 8 collection for a single path-row.
collection = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').filter(ee.Filter.eq('WRS_PATH', 44)).filter(ee.Filter.eq('WRS_ROW', 34)).filterDate('2014-01-01', '2015-01-01')

# Compute a median image and display.
median = collection.median()

dicc = {
    'median' : median.getMapId({'bands': ['B4', 'B3', 'B2'], 'max': 0.3})
}

# Display the results
center = [37.7726, -122.3578]
Mapdisplay(center, dicc, zoom_start= 12)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# At each location in the output image, in each band, the pixel value is the median of all unmasked pixels in the input imagery (the images in the collection). In the previous example, median() is a convenience method for the following call:

# %%
# Reduce the collection with a median reducer.
median = collection.reduce(ee.Reducer.median())

# Display the median image.
dicc = {'also median' : median.getMapId({'bands': ['B4_median', 'B3_median', 'B2_median'], 'max': 0.3})}

# Display the results
center = [37.7726, -122.3578]
Mapdisplay(center, dicc, zoom_start= 12)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Note that the band names differ as a result of using reduce() instead of the convenience method. Specifically, the names of the reducer have been appended to the band names.
#
# More complex reductions are also possible using reduce(). For example, to compute the long term linear trend over a collection, use one of the linear regression reducers. The following code computes the linear trend of MODIS Enhanced Vegetation Index (EVI).

# %%
# This function adds a band representing the image timestamp.
def addTime(image):
  return image.addBands(image.metadata('system:time_start').divide(1000 * 60 * 60 * 24 * 365))

# Load a MODIS collection, filter to several years of 16 day mosaics, and map the time band function over it.
collection = ee.ImageCollection('MODIS/006/MYD13A1').filterDate('2004-01-01', '2010-10-31').map(addTime)

# Select the bands to model with the independent variable first.
# Compute the linear trend over time.
trend = collection.select(['system:time_start', 'EVI']).reduce(ee.Reducer.linearFit())

# Display the trend with increasing slopes in green, decreasing in red.
dicc = {
    'EVI trend' : trend.getMapId({'min': 0, 'max': [-100, 100, 10000], 'bands': ['scale', 'scale', 'offset']})
}

# Display the results
center = [39.436, -96.943]
Mapdisplay(center, dicc, zoom_start= 5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Note that the output of the reduction in this example is a two banded image with one band for the slope of a linear regression (**scale**) and one band for the intercept (**offset**). Explore the API documentation to see a list of the reducers that are available to reduce an **ImageCollection** to a single Image. See the **ImageCollection.reduce()** section for more information about reducing image collections.

# %% [markdown]
# # 6. Compositing and Mosaicking
#
# In general, compositing refers to the process of combining spatially overlapping images into a single image based on an aggregation function. Mosaicking refers to the process of spatially assembling image datasets to produce a spatially continuous image. In Earth Engine, these terms are used interchangeably, though both compositing and mosaicking are supported. For example, consider the task of compositing multiple images in the same location. For example, using one National Agriculture Imagery Program (NAIP) Digital Orthophoto Quarter Quadrangle (DOQQ) at different times, the following example demonstrates making a maximum value composite:

# %%
# Load three NAIP quarter quads in the same location, different times.
naip2004_2012 = ee.ImageCollection('USDA/NAIP/DOQQ')\
                  .filterBounds(ee.Geometry.Point(-71.08841, 42.39823))\
                  .filterDate('2004-07-01', '2012-12-31')\
                  .select(['R', 'G', 'B'])

# Temporally composite the images with a maximum value function.
composite = naip2004_2012.max()
center = [42.3712, -71.12532]
Mapdisplay(center, {'max value composite':composite.getMapId()},zoom_start=12)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Consider the need to mosaic four different DOQQs at the same time, but different locations. The following example demonstrates that using **imageCollection.mosaic()**:

# %%
# Load four 2012 NAIP quarter quads, different locations.
naip2012 = ee.ImageCollection('USDA/NAIP/DOQQ')\
             .filterBounds(ee.Geometry.Rectangle(-71.17965, 42.35125, -71.08824, 42.40584))\
             .filterDate('2012-01-01', '2012-12-31')

# Spatially mosaic the images in the collection and display.
mosaic = naip2012.mosaic()
center = [42.3712,-71.12532]
Mapdisplay(center,{'spatial mosaic':mosaic.getMapId()},zoom_start=12)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Note that there is some overlap in the DOQQs in the previous example. The **mosaic()** method composites overlapping images according to their order in the collection (last on top). To control the source of pixels in a mosaic (or a composite), use image masks. For example, the following uses thresholds on spectral indices to mask the image data in a mosaic:

# %%
# Load a NAIP quarter quad, display.
naip = ee.Image('USDA/NAIP/DOQQ/m_4207148_nw_19_1_20120710')

# Create the NDVI and NDWI spectral indices.
ndvi = naip.normalizedDifference(['N', 'R'])
ndwi = naip.normalizedDifference(['G', 'N'])

# Create some binary images from thresholds on the indices.
# This threshold is designed to detect bare land.
bare1 = ndvi.lt(0.2).And(ndwi.lt(0.3))
# This detects bare land with lower sensitivity. It also detects shadows.
bare2 = ndvi.lt(0.2).And(ndwi.lt(0.8));

# Define visualization parameters for the spectral indices.
ndviViz = {'min': -1, 'max': 1, 'palette': ['FF0000', '00FF00']}
ndwiViz = {'min': 0.5, 'max': 1, 'palette': ['00FFFF', '0000FF']}

# Mask and mosaic visualization images.  The last layer is on top.
mosaic = ee.ImageCollection([
  # NDWI > 0.5 is water.  Visualize it with a blue palette.
  ndwi.updateMask(ndwi.gte(0.5)).visualize(**ndwiViz),
  # NDVI > 0.2 is vegetation.  Visualize it with a green palette.
  ndvi.updateMask(ndvi.gte(0.2)).visualize(**ndviViz),
  # Visualize bare areas with shadow (bare2 but not bare1) as gray.
  bare2.updateMask(bare2.And(bare1.Not())).visualize(**{'palette': ['AAAAAA']}),
  # Visualize the other bare areas as white.
  bare1.updateMask(bare1).visualize(**{'palette': ['FFFFFF']}),
]).mosaic()

center = [42.3443, -71.0915]
dicc = {'NAIP DOQQ':naip.getMapId(),
        'Visualization mosaic':mosaic.getMapId()}
Mapdisplay(center,dicc,zoom_start=14)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# To make a composite which maximizes an arbitrary band in the input, use **imageCollection.qualityMosaic()**. The **qualityMosaic()** method sets each pixel in the composite based on which image in the collection has a maximum value for the specified band. For example, the following code demonstrates making a greenest pixel composite and a recent value composite:

# %%
# This function masks clouds in Landsat 8 imagery.
def maskClouds(img):
  scored = ee.Algorithms.Landsat.simpleCloudScore(img)
  return img.updateMask(scored.select(['cloud']).lt(20))


# This function masks clouds and adds quality bands to Landsat 8 images.
def addQualityBands(img):
  return maskClouds(img).addBands(img.normalizedDifference(['B5', 'B4']))\
                          .addBands(img.metadata('system:time_start')) # time in days


# Load a 2014 Landsat 8 ImageCollection.
# Map the cloud masking and quality band function over the collection.
collection = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA')\
               .filterDate('2014-06-01', '2014-12-31')\
               .map(addQualityBands)

# Create a cloud-free, most recent value composite.
recentValueComposite = collection.qualityMosaic('system:time_start')

# Create a greenest pixel composite.
greenestPixelComposite = collection.qualityMosaic('nd')


# Create a cloudy image in the collection.
cloudy = ee.Image('LANDSAT/LC08/C01/T1_TOA/LC08_044034_20140825');

# Display the results.
center = [37.8239, -122.374] # San Francisco Bay
vizParams = {'bands': ['B5', 'B4', 'B3'], 'min': 0, 'max': 0.4}
dicc = {'recent value composite':recentValueComposite.getMapId(vizParams),
        'greenest pixel composite':greenestPixelComposite.getMapId(vizParams),
        'cloudy':cloudy.getMapId(vizParams)}

Mapdisplay(center,dicc,zoom_start=12)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 7. Iterating over an ImageCollection
#
# Although `map()` applies a function to every image in a collection, the function visits every image in the collection independently. For example, suppose you want to compute a cumulative anomaly ($A_t$) at time t from a time series. To obtain a recursively defined series of the form $A_t = f(Image_t, A_{t-1})$, mapping won't work because the function (f) depends on the previous result ($A{t-1}$).
#
# For example, suppose you want to compute a series of cumulative Normalized Difference Vegetation Index (NDVI) anomaly images relative to a baseline. Let $A_0 = 0$ and $f(Image_t, A_{t-1}) = Image_t + A_{t-1}$ where $A_{t-1}$ is the cumulative anomaly up to time $t-1$ and Image_t is the anomaly at time t. Use **imageCollection.iterate()** to make this recursively defined ImageCollection. In the following example, the function **accumulate()** takes two parameters: an image in the collection, and a list of all the previous outputs. With each call to **iterate()**, the anomaly is added to the running sum and the result is added to the list. The final result is passed to the **ImageCollection** constructor to get a new sequence of images:

# %%
# Load MODIS EVI imagery.
collection = ee.ImageCollection('MODIS/006/MYD13A1').select('EVI');

# Define reference conditions from the first 10 years of data.
reference = collection.filterDate('2001-01-01', '2010-12-31')\
                      .sort('system:time_start', False) # Sort chronologically in descending order.

# Compute the mean of the first 10 years.
mean = reference.mean()

# Compute anomalies by subtracting the 2001-2010 mean from each image in a
# collection of 2011-2014 images. Copy the date metadata over to the
# computed anomaly images in the new collection.
series = collection.filterDate('2011-01-01', '2014-12-31')\
                   .map(lambda img: img.subtract(mean).set('system:time_start', img.get('system:time_start')))

# Display cumulative anomalies.
center = [40.2,-100.811]
vizParams = {'min': -60000, 'max': 60000, 'palette': ['FF0000', '000000', '00FF00']}
dicc = {'EVI anomaly':series.sum().getMapId(vizParams)}
Mapdisplay(center,dicc,zoom_start=5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Get the timestamp from the most recent image in the reference collection.
time0 = reference.first().get('system:time_start')

# Use imageCollection.iterate() to make a collection of cumulative anomaly over time.
# The initial value for iterate() is a list of anomaly images already processed.
# The first anomaly image in the list is just 0, with the time0 timestamp.
first = ee.List([ee.Image(0).set('system:time_start', time0).select([0], ['EVI'])]) # Rename the first band 'EVI'.

# This is a function to pass to Iterate().
# As anomaly images are computed, add them to the list.
def accumulate(img,lista):
  # Get the latest cumulative anomaly image from the end of the list with
  # get(-1).  Since the type of the list argument to the function is unknown,
  # it needs to be cast to a List.  Since the return type of get() is unknown,
  # cast it to Image.
  img = ee.Image(img)
  previous = ee.Image(ee.List(lista).get(-1))
  # Add the current anomaly to make a new cumulative anomaly image.
  added = img.add(previous)\
               .set('system:time_start', img.get('system:time_start')) # Propagate metadata to the new image.
  # Return the list with the cumulative anomaly inserted.
  return ee.List(lista).add(added)

# Create an ImageCollection of cumulative anomaly images by iterating.
# Since the return type of iterate is unknown, it needs to be cast to a List.
cumulative = ee.ImageCollection(ee.List(series.iterate(accumulate, first)))

# %%
def stackCollection(collection):
  # Create an initial image.
  first = ee.Image(collection.first()).select([])

  # Write a function that appends a band to an image.
  def appendBands(image, previous):
    return ee.Image(previous).addBands(image)
  return ee.Image(collection.iterate(appendBands, first))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Chart some interesting locations.
pt1 = ee.Geometry.Point(116.4647, 40.1054)

# ee.ImageCollection to ee.Image
img_cumulative = stackCollection(cumulative)


series = img_cumulative.reduceRegions(collection=pt1,
                                      reducer=ee.Reducer.mean(),
                                      scale=500)

dic_series = series.getInfo()
EVI_anom = np.array(list(dic_series['features'][0]['properties'].values()))

plt.plot(EVI_anom)
plt.show()

# %% [markdown]
# ---
